# %% [markdown]
# # Challenge 1
#
# In this challenge you will be working on **Pokemon**. You will answer a series of questions in order to practice dataframe calculation, aggregation, and transformation.
#
# ![Pokemon](../images/pokemon.jpg)
#
# Follow the instructions below and enter your code.
#
# #### Import all required libraries.

# %%
# import libraries
import pandas as pd

# %% [markdown]
# #### Import data set.
#
# Import data set `Pokemon` from Ironhack's database. Read the data into a dataframe called `pokemon`.
#
# *Data set attributed to [Alberto Barradas](https://www.kaggle.com/abcsds/pokemon/)*

# %%
# import data set from Ironhack's database
pokemon = pd.read_csv('../pokemon.csv')

# %%
pokemon
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# 1         80       80     60           1      False
# 2        100      100     80           1      False
# 3        122      120     80           1      False
# 4         60       50     65           1      False
# ..       ...      ...    ...         ...        ...
# 795      100      150     50           6       True
# 796      160      110    110           6       True
# 797      150      130     70           6       True
# 798      170      130     80           6       True
# 799      130       90     70           6       True
#
# [800 rows x 13 columns]

# %% [markdown]
# #### Print first 10 rows of `pokemon`.

# %%
# your code here
pokemon.head(10)
# Out:
#    #                       Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1                  Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                    Ivysaur  Grass  Poison    405  60      62       63
# 2  3                   Venusaur  Grass  Poison    525  80      82       83
# 3  3      VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4                 Charmander   Fire     NaN    309  39      52       43
# 5  5                 Charmeleon   Fire     NaN    405  58      64       58
# 6  6                  Charizard   Fire  Flying    534  78      84       78
# 7  6  CharizardMega Charizard X   Fire  Dragon    634  78     130      111
# 8  6  CharizardMega Charizard Y   Fire  Flying    634  78     104       78
# 9  7                   Squirtle  Water     NaN    314  44      48       65
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False
# 5       80       65     80           1      False
# 6      109       85    100           1      False
# 7      130       85    100           1      False
# 8      159      115    100           1      False
# 9       50       64     43           1      False

# %% [markdown]
# When you look at a data set, you often wonder what each column means. Some open-source data sets provide descriptions of the data set. In many cases, data descriptions are extremely useful for data analysts to perform work efficiently and successfully.
#
# For the `Pokemon.csv` data set, fortunately, the owner provided descriptions which you can see [here](https://www.kaggle.com/abcsds/pokemon/home). For your convenience, we are including the descriptions below. Read the descriptions and understand what each column means. This knowledge is helpful in your work with the data.
#
# | Column | Description |
# | --- | --- |
# | # | ID for each pokemon |
# | Name | Name of each pokemon |
# | Type 1 | Each pokemon has a type, this determines weakness/resistance to attacks |
# | Type 2 | Some pokemon are dual type and have 2 |
# | Total | A general guide to how strong a pokemon is |
# | HP | Hit points, or health, defines how much damage a pokemon can withstand before fainting |
# | Attack | The base modifier for normal attacks (eg. Scratch, Punch) |
# | Defense | The base damage resistance against normal attacks |
# | SP Atk | Special attack, the base modifier for special attacks (e.g. fire blast, bubble beam) |
# | SP Def | The base damage resistance against special attacks |
# | Speed | Determines which pokemon attacks first each round |
# | Generation | Number of generation |
# | Legendary | True if Legendary Pokemon False if not |

# %% [markdown]
# #### Obtain the distinct values across `Type 1` and `Type 2`.
#
# Exctract all the values in `Type 1` and `Type 2`. Then create an array containing the distinct values across both fields.

# %%
# your code here
type_1 = pokemon['Type 1'].unique()
type_2 = pokemon['Type 2'].unique()

pd.array([type_1,type_2])
# Out:
# <PandasArray>
# [array(['Grass', 'Fire', 'Water', 'Bug', 'Normal', 'Poison', 'Electric',
#        'Ground', 'Fairy', 'Fighting', 'Psychic', 'Rock', 'Ghost', 'Ice',
#        'Dragon', 'Dark', 'Steel', 'Flying'], dtype=object), array(['Poison', nan, 'Flying', 'Dragon', 'Ground', 'Fairy', 'Grass',
#        'Fighting', 'Psychic', 'Steel', 'Ice', 'Rock', 'Dark', 'Water',
#        'Electric', 'Fire', 'Ghost', 'Bug', 'Normal'], dtype=object)]
# Length: 2, dtype: object

# %%
pokemon.rename(columns={'Type 1':'t1','Type 2':'t2'},inplace=True)

# %%
pokemon[['t1','t2']].apply(lambda x: tuple(set((x['t1'],x['t2']))),axis=1).values
# Out:
# array([('Grass', 'Poison'), ('Grass', 'Poison'), ('Grass', 'Poison'),
#        ('Grass', 'Poison'), (nan, 'Fire'), (nan, 'Fire'),
#        ('Flying', 'Fire'), ('Dragon', 'Fire'), ('Flying', 'Fire'),
#        (nan, 'Water'), (nan, 'Water'), (nan, 'Water'), (nan, 'Water'),
#        (nan, 'Bug'), (nan, 'Bug'), ('Flying', 'Bug'), ('Poison', 'Bug'),
#        ('Poison', 'Bug'), ('Poison', 'Bug'), ('Poison', 'Bug'),
#        ('Normal', 'Flying'), ('Normal', 'Flying'), ('Normal', 'Flying'),
#        ('Normal', 'Flying'), ('Normal', nan), ('Normal', nan),
#        ('Normal', 'Flying'), ('Normal', 'Flying'), (nan, 'Poison'),
#        (nan, 'Poison'), (nan, 'Electric'), (nan, 'Electric'),
#        (nan, 'Ground'), (nan, 'Ground'), (nan, 'Poison'), (nan, 'Poison'),
#        ('Poison', 'Ground'), (nan, 'Poison'), (nan, 'Poison'),
#        ('Poison', 'Ground'), (nan, 'Fairy'), (nan, 'Fairy'),
#        (nan, 'Fire'), (nan, 'Fire'), ('Normal', 'Fairy'),
#        ('Normal', 'Fairy'), ('Flying', 'Poison'), ('Flying', 'Poison'),
#        ('Grass', 'Poison'), ('Grass', 'Poison'), ('Grass', 'Poison'),
#        ('Grass', 'Bug'), ('Grass', 'Bug'), ('Poison', 'Bug'),
#        ('Poison', 'Bug'), (nan, 'Ground'), (nan, 'Ground'),
#        ('Normal', nan), ('Normal', nan), (nan, 'Water'), (nan, 'Water'),
#        (nan, 'Fighting'), (nan, 'Fighting'), (nan, 'Fire'), (nan, 'Fire'),
#        (nan, 'Water'), (nan, 'Water'), ('Fighting', 'Water'),
#        (nan, 'Psychic'), (nan, 'Psychic'), (nan, 'Psychic'),
#        (nan, 'Psychic'), (nan, 'Fighting'), (nan, 'Fighting'),
#        (nan, 'Fighting'), ('Grass', 'Poison'), ('Grass', 'Poison'),
#        ('Grass', 'Poison'), ('Poison', 'Water'), ('Poison', 'Water'),
#        ('Ground', 'Rock'), ('Ground', 'Rock'), ('Ground', 'Rock'),
#        (nan, 'Fire'), (nan, 'Fire'), ('Psychic', 'Water'),
#        ('Psychic', 'Water'), ('Psychic', 'Water'), ('Electric', 'Steel'),
#        ('Electric', 'Steel'), ('Normal', 'Flying'), ('Normal', 'Flying'),
#        ('Normal', 'Flying'), (nan, 'Water'), ('Ice', 'Water'),
#        (nan, 'Poison'), (nan, 'Poison'), (nan, 'Water'), ('Ice', 'Water'),
#        ('Ghost', 'Poison'), ('Ghost', 'Poison'), ('Ghost', 'Poison'),
#        ('Ghost', 'Poison'), ('Ground', 'Rock'), (nan, 'Psychic'),
#        (nan, 'Psychic'), (nan, 'Water'), (nan, 'Water'),
#        (nan, 'Electric'), (nan, 'Electric'), ('Grass', 'Psychic'),
#        ('Grass', 'Psychic'), (nan, 'Ground'), (nan, 'Ground'),
#        (nan, 'Fighting'), (nan, 'Fighting'), ('Normal', nan),
#        (nan, 'Poison'), (nan, 'Poison'), ('Rock', 'Ground'),
#        ('Rock', 'Ground'), ('Normal', nan), (nan, 'Grass'),
#        ('Normal', nan), ('Normal', nan), (nan, 'Water'), (nan, 'Water'),
#        (nan, 'Water'), (nan, 'Water'), (nan, 'Water'),
#        ('Psychic', 'Water'), ('Fairy', 'Psychic'), ('Flying', 'Bug'),
#        ('Ice', 'Psychic'), (nan, 'Electric'), (nan, 'Fire'), (nan, 'Bug'),
#        ('Flying', 'Bug'), ('Normal', nan), (nan, 'Water'),
#        ('Flying', 'Water'), ('Dark', 'Water'), ('Ice', 'Water'),
#        ('Normal', nan), ('Normal', nan), (nan, 'Water'),
#        (nan, 'Electric'), (nan, 'Fire'), ('Normal', nan),
#        ('Rock', 'Water'), ('Rock', 'Water'), ('Rock', 'Water'),
#        ('Rock', 'Water'), ('Flying', 'Rock'), ('Flying', 'Rock'),
#        ('Normal', nan), ('Flying', 'Ice'), ('Electric', 'Flying'),
#        ('Flying', 'Fire'), (nan, 'Dragon'), (nan, 'Dragon'),
#        ('Flying', 'Dragon'), (nan, 'Psychic'), ('Psychic', 'Fighting'),
#        (nan, 'Psychic'), (nan, 'Psychic'), (nan, 'Grass'), (nan, 'Grass'),
#        (nan, 'Grass'), (nan, 'Fire'), (nan, 'Fire'), (nan, 'Fire'),
#        (nan, 'Water'), (nan, 'Water'), (nan, 'Water'), ('Normal', nan),
#        ('Normal', nan), ('Normal', 'Flying'), ('Normal', 'Flying'),
#        ('Flying', 'Bug'), ('Flying', 'Bug'), ('Poison', 'Bug'),
#        ('Poison', 'Bug'), ('Flying', 'Poison'), ('Electric', 'Water'),
#        ('Electric', 'Water'), (nan, 'Electric'), (nan, 'Fairy'),
#        ('Normal', 'Fairy'), (nan, 'Fairy'), ('Flying', 'Fairy'),
#        ('Flying', 'Psychic'), ('Flying', 'Psychic'), (nan, 'Electric'),
#        (nan, 'Electric'), (nan, 'Electric'), ('Electric', 'Dragon'),
#        (nan, 'Grass'), ('Fairy', 'Water'), ('Fairy', 'Water'),
#        (nan, 'Rock'), (nan, 'Water'), ('Grass', 'Flying'),
#        ('Grass', 'Flying'), ('Grass', 'Flying'), ('Normal', nan),
#        (nan, 'Grass'), (nan, 'Grass'), ('Flying', 'Bug'),
#        ('Ground', 'Water'), ('Ground', 'Water'), (nan, 'Psychic'),
#        (nan, 'Dark'), ('Dark', 'Flying'), ('Psychic', 'Water'),
#        (nan, 'Ghost'), (nan, 'Psychic'), (nan, 'Psychic'),
#        ('Normal', 'Psychic'), (nan, 'Bug'), ('Steel', 'Bug'),
#        ('Normal', nan), ('Flying', 'Ground'), ('Steel', 'Ground'),
#        ('Steel', 'Ground'), (nan, 'Fairy'), (nan, 'Fairy'),
#        ('Poison', 'Water'), ('Steel', 'Bug'), ('Steel', 'Bug'),
#        ('Rock', 'Bug'), ('Fighting', 'Bug'), ('Fighting', 'Bug'),
#        ('Dark', 'Ice'), ('Normal', nan), ('Normal', nan), (nan, 'Fire'),
#        ('Rock', 'Fire'), ('Ice', 'Ground'), ('Ice', 'Ground'),
#        ('Rock', 'Water'), (nan, 'Water'), (nan, 'Water'),
#        ('Flying', 'Ice'), ('Flying', 'Water'), ('Flying', 'Steel'),
#        ('Dark', 'Fire'), ('Dark', 'Fire'), ('Dark', 'Fire'),
#        ('Dragon', 'Water'), (nan, 'Ground'), (nan, 'Ground'),
#        ('Normal', nan), ('Normal', nan), ('Normal', nan),
#        (nan, 'Fighting'), (nan, 'Fighting'), ('Ice', 'Psychic'),
#        (nan, 'Electric'), (nan, 'Fire'), ('Normal', nan), ('Normal', nan),
#        (nan, 'Electric'), (nan, 'Fire'), (nan, 'Water'),
#        ('Ground', 'Rock'), ('Ground', 'Rock'), ('Dark', 'Rock'),
#        ('Dark', 'Rock'), ('Flying', 'Psychic'), ('Flying', 'Fire'),
#        ('Grass', 'Psychic'), (nan, 'Grass'), (nan, 'Grass'),
#        (nan, 'Grass'), ('Grass', 'Dragon'), (nan, 'Fire'),
#        ('Fire', 'Fighting'), ('Fire', 'Fighting'), ('Fire', 'Fighting'),
#        (nan, 'Water'), ('Ground', 'Water'), ('Ground', 'Water'),
#        ('Ground', 'Water'), (nan, 'Dark'), (nan, 'Dark'), ('Normal', nan),
#        ('Normal', nan), (nan, 'Bug'), (nan, 'Bug'), ('Flying', 'Bug'),
#        (nan, 'Bug'), ('Poison', 'Bug'), ('Grass', 'Water'),
#        ('Grass', 'Water'), ('Grass', 'Water'), (nan, 'Grass'),
#        ('Grass', 'Dark'), ('Grass', 'Dark'), ('Normal', 'Flying'),
#        ('Normal', 'Flying'), ('Flying', 'Water'), ('Flying', 'Water'),
#        ('Fairy', 'Psychic'), ('Fairy', 'Psychic'), ('Fairy', 'Psychic'),
#        ('Fairy', 'Psychic'), ('Water', 'Bug'), ('Flying', 'Bug'),
#        (nan, 'Grass'), ('Grass', 'Fighting'), ('Normal', nan),
#        ('Normal', nan), ('Normal', nan), ('Ground', 'Bug'),
#        ('Flying', 'Bug'), ('Ghost', 'Bug'), ('Normal', nan),
#        ('Normal', nan), ('Normal', nan), (nan, 'Fighting'),
#        (nan, 'Fighting'), ('Normal', 'Fairy'), (nan, 'Rock'),
#        ('Normal', nan), ('Normal', nan), ('Ghost', 'Dark'),
#        ('Ghost', 'Dark'), ('Fairy', 'Steel'), ('Fairy', 'Steel'),
#        ('Steel', 'Rock'), ('Steel', 'Rock'), ('Steel', 'Rock'),
#        (nan, 'Steel'), ('Psychic', 'Fighting'), ('Psychic', 'Fighting'),
#        ('Psychic', 'Fighting'), (nan, 'Electric'), (nan, 'Electric'),
#        (nan, 'Electric'), (nan, 'Electric'), (nan, 'Electric'),
#        (nan, 'Bug'), (nan, 'Bug'), ('Grass', 'Poison'), (nan, 'Poison'),
#        (nan, 'Poison'), ('Dark', 'Water'), ('Dark', 'Water'),
#        ('Dark', 'Water'), (nan, 'Water'), (nan, 'Water'),
#        ('Ground', 'Fire'), ('Ground', 'Fire'), ('Ground', 'Fire'),
#        (nan, 'Fire'), (nan, 'Psychic'), (nan, 'Psychic'), ('Normal', nan),
#        (nan, 'Ground'), ('Dragon', 'Ground'), ('Dragon', 'Ground'),
#        (nan, 'Grass'), ('Grass', 'Dark'), ('Normal', 'Flying'),
#        ('Flying', 'Dragon'), ('Dragon', 'Fairy'), ('Normal', nan),
#        (nan, 'Poison'), ('Psychic', 'Rock'), ('Psychic', 'Rock'),
#        ('Ground', 'Water'), ('Ground', 'Water'), (nan, 'Water'),
#        ('Dark', 'Water'), ('Psychic', 'Ground'), ('Psychic', 'Ground'),
#        ('Grass', 'Rock'), ('Grass', 'Rock'), ('Rock', 'Bug'),
#        ('Rock', 'Bug'), (nan, 'Water'), (nan, 'Water'), ('Normal', nan),
#        ('Normal', nan), (nan, 'Ghost'), (nan, 'Ghost'), (nan, 'Ghost'),
#        (nan, 'Ghost'), (nan, 'Ghost'), ('Grass', 'Flying'),
#        (nan, 'Psychic'), (nan, 'Dark'), (nan, 'Dark'), (nan, 'Psychic'),
#        (nan, 'Ice'), (nan, 'Ice'), (nan, 'Ice'), ('Ice', 'Water'),
#        ('Ice', 'Water'), ('Ice', 'Water'), (nan, 'Water'), (nan, 'Water'),
#        (nan, 'Water'), ('Rock', 'Water'), (nan, 'Water'), (nan, 'Dragon'),
#        (nan, 'Dragon'), ('Flying', 'Dragon'), ('Flying', 'Dragon'),
#        ('Psychic', 'Steel'), ('Psychic', 'Steel'), ('Psychic', 'Steel'),
#        ('Psychic', 'Steel'), (nan, 'Rock'), (nan, 'Ice'), (nan, 'Steel'),
#        ('Dragon', 'Psychic'), ('Dragon', 'Psychic'),
#        ('Dragon', 'Psychic'), ('Dragon', 'Psychic'), (nan, 'Water'),
#        (nan, 'Water'), (nan, 'Ground'), ('Fire', 'Ground'),
#        ('Flying', 'Dragon'), ('Flying', 'Dragon'), ('Psychic', 'Steel'),
#        (nan, 'Psychic'), (nan, 'Psychic'), (nan, 'Psychic'),
#        (nan, 'Psychic'), (nan, 'Grass'), (nan, 'Grass'),
#        ('Grass', 'Ground'), (nan, 'Fire'), ('Fire', 'Fighting'),
#        ('Fire', 'Fighting'), (nan, 'Water'), (nan, 'Water'),
#        ('Steel', 'Water'), ('Normal', 'Flying'), ('Normal', 'Flying'),
#        ('Normal', 'Flying'), ('Normal', nan), ('Normal', 'Water'),
#        (nan, 'Bug'), (nan, 'Bug'), (nan, 'Electric'), (nan, 'Electric'),
#        (nan, 'Electric'), ('Grass', 'Poison'), ('Grass', 'Poison'),
#        (nan, 'Rock'), (nan, 'Rock'), ('Steel', 'Rock'), ('Steel', 'Rock'),
#        (nan, 'Bug'), ('Grass', 'Bug'), ('Ground', 'Bug'),
#        ('Steel', 'Bug'), ('Flying', 'Bug'), ('Flying', 'Bug'),
#        ('Flying', 'Bug'), (nan, 'Electric'), (nan, 'Water'),
#        (nan, 'Water'), (nan, 'Grass'), (nan, 'Grass'), (nan, 'Water'),
#        ('Ground', 'Water'), ('Normal', nan), ('Ghost', 'Flying'),
#        ('Ghost', 'Flying'), ('Normal', nan), ('Normal', nan),
#        ('Normal', 'Fighting'), (nan, 'Ghost'), ('Dark', 'Flying'),
#        ('Normal', nan), ('Normal', nan), (nan, 'Psychic'),
#        ('Dark', 'Poison'), ('Dark', 'Poison'), ('Psychic', 'Steel'),
#        ('Psychic', 'Steel'), (nan, 'Rock'), ('Fairy', 'Psychic'),
#        ('Normal', nan), ('Normal', 'Flying'), ('Ghost', 'Dark'),
#        ('Dragon', 'Ground'), ('Dragon', 'Ground'), ('Dragon', 'Ground'),
#        ('Dragon', 'Ground'), ('Normal', nan), (nan, 'Fighting'),
#        ('Steel', 'Fighting'), ('Steel', 'Fighting'), (nan, 'Ground'),
#        (nan, 'Ground'), ('Poison', 'Bug'), ('Dark', 'Poison'),
#        ('Poison', 'Fighting'), ('Poison', 'Fighting'), (nan, 'Grass'),
#        (nan, 'Water'), (nan, 'Water'), ('Flying', 'Water'),
#        ('Grass', 'Ice'), ('Grass', 'Ice'), ('Grass', 'Ice'),
#        ('Dark', 'Ice'), ('Electric', 'Steel'), ('Normal', nan),
#        ('Rock', 'Ground'), (nan, 'Grass'), (nan, 'Electric'),
#        (nan, 'Fire'), ('Flying', 'Fairy'), ('Flying', 'Bug'),
#        (nan, 'Grass'), (nan, 'Ice'), ('Flying', 'Ground'),
#        ('Ice', 'Ground'), ('Normal', nan), ('Psychic', 'Fighting'),
#        ('Psychic', 'Fighting'), ('Steel', 'Rock'), (nan, 'Ghost'),
#        ('Ghost', 'Ice'), ('Ghost', 'Electric'), ('Electric', 'Fire'),
#        ('Electric', 'Water'), ('Electric', 'Ice'), ('Electric', 'Flying'),
#        ('Electric', 'Grass'), (nan, 'Psychic'), (nan, 'Psychic'),
#        (nan, 'Psychic'), ('Dragon', 'Steel'), ('Dragon', 'Water'),
#        ('Steel', 'Fire'), ('Normal', nan), ('Ghost', 'Dragon'),
#        ('Ghost', 'Dragon'), (nan, 'Psychic'), (nan, 'Water'),
#        (nan, 'Water'), (nan, 'Dark'), (nan, 'Grass'), ('Grass', 'Flying'),
#        ('Normal', nan), ('Psychic', 'Fire'), (nan, 'Grass'),
#        (nan, 'Grass'), (nan, 'Grass'), (nan, 'Fire'),
#        ('Fire', 'Fighting'), ('Fire', 'Fighting'), (nan, 'Water'),
#        (nan, 'Water'), (nan, 'Water'), ('Normal', nan), ('Normal', nan),
#        ('Normal', nan), ('Normal', nan), ('Normal', nan), (nan, 'Dark'),
#        (nan, 'Dark'), (nan, 'Grass'), (nan, 'Grass'), (nan, 'Fire'),
#        (nan, 'Fire'), (nan, 'Water'), (nan, 'Water'), (nan, 'Psychic'),
#        (nan, 'Psychic'), ('Normal', 'Flying'), ('Normal', 'Flying'),
#        ('Normal', 'Flying'), (nan, 'Electric'), (nan, 'Electric'),
#        (nan, 'Rock'), (nan, 'Rock'), (nan, 'Rock'), ('Flying', 'Psychic'),
#        ('Flying', 'Psychic'), (nan, 'Ground'), ('Steel', 'Ground'),
#        ('Normal', nan), ('Normal', 'Fairy'), (nan, 'Fighting'),
#        (nan, 'Fighting'), (nan, 'Fighting'), (nan, 'Water'),
#        ('Ground', 'Water'), ('Ground', 'Water'), (nan, 'Fighting'),
#        (nan, 'Fighting'), ('Grass', 'Bug'), ('Grass', 'Bug'),
#        ('Grass', 'Bug'), ('Poison', 'Bug'), ('Poison', 'Bug'),
#        ('Poison', 'Bug'), ('Grass', 'Fairy'), ('Grass', 'Fairy'),
#        (nan, 'Grass'), (nan, 'Grass'), (nan, 'Water'), ('Dark', 'Ground'),
#        ('Dark', 'Ground'), ('Dark', 'Ground'), (nan, 'Fire'),
#        (nan, 'Fire'), ('Psychic', 'Fire'), (nan, 'Grass'),
#        ('Rock', 'Bug'), ('Rock', 'Bug'), ('Dark', 'Fighting'),
#        ('Dark', 'Fighting'), ('Flying', 'Psychic'), (nan, 'Ghost'),
#        (nan, 'Ghost'), ('Rock', 'Water'), ('Rock', 'Water'),
#        ('Flying', 'Rock'), ('Flying', 'Rock'), (nan, 'Poison'),
#        (nan, 'Poison'), (nan, 'Dark'), (nan, 'Dark'), ('Normal', nan),
#        ('Normal', nan), (nan, 'Psychic'), (nan, 'Psychic'),
#        (nan, 'Psychic'), (nan, 'Psychic'), (nan, 'Psychic'),
#        (nan, 'Psychic'), ('Flying', 'Water'), ('Flying', 'Water'),
#        (nan, 'Ice'), (nan, 'Ice'), (nan, 'Ice'), ('Normal', 'Grass'),
#        ('Normal', 'Grass'), ('Electric', 'Flying'), (nan, 'Bug'),
#        ('Steel', 'Bug'), ('Grass', 'Poison'), ('Grass', 'Poison'),
#        ('Ghost', 'Water'), ('Ghost', 'Water'), (nan, 'Water'),
#        ('Electric', 'Bug'), ('Electric', 'Bug'), ('Grass', 'Steel'),
#        ('Grass', 'Steel'), (nan, 'Steel'), (nan, 'Steel'), (nan, 'Steel'),
#        (nan, 'Electric'), (nan, 'Electric'), (nan, 'Electric'),
#        (nan, 'Psychic'), (nan, 'Psychic'), ('Ghost', 'Fire'),
#        ('Ghost', 'Fire'), ('Ghost', 'Fire'), (nan, 'Dragon'),
#        (nan, 'Dragon'), (nan, 'Dragon'), (nan, 'Ice'), (nan, 'Ice'),
#        (nan, 'Ice'), (nan, 'Bug'), (nan, 'Bug'), ('Electric', 'Ground'),
#        (nan, 'Fighting'), (nan, 'Fighting'), (nan, 'Dragon'),
#        ('Ghost', 'Ground'), ('Ghost', 'Ground'), ('Dark', 'Steel'),
#        ('Dark', 'Steel'), ('Normal', nan), ('Normal', 'Flying'),
#        ('Normal', 'Flying'), ('Dark', 'Flying'), ('Dark', 'Flying'),
#        (nan, 'Fire'), ('Steel', 'Bug'), ('Dark', 'Dragon'),
#        ('Dark', 'Dragon'), ('Dark', 'Dragon'), ('Fire', 'Bug'),
#        ('Fire', 'Bug'), ('Steel', 'Fighting'), ('Rock', 'Fighting'),
#        ('Grass', 'Fighting'), (nan, 'Flying'), (nan, 'Flying'),
#        ('Electric', 'Flying'), ('Electric', 'Flying'), ('Dragon', 'Fire'),
#        ('Electric', 'Dragon'), ('Flying', 'Ground'), ('Flying', 'Ground'),
#        ('Ice', 'Dragon'), ('Ice', 'Dragon'), ('Ice', 'Dragon'),
#        ('Fighting', 'Water'), ('Fighting', 'Water'),
#        ('Normal', 'Psychic'), ('Normal', 'Fighting'), ('Steel', 'Bug'),
#        (nan, 'Grass'), (nan, 'Grass'), ('Grass', 'Fighting'),
#        (nan, 'Fire'), (nan, 'Fire'), ('Psychic', 'Fire'), (nan, 'Water'),
#        (nan, 'Water'), ('Dark', 'Water'), ('Normal', nan),
#        ('Normal', 'Ground'), ('Normal', 'Flying'), ('Flying', 'Fire'),
#        ('Flying', 'Fire'), (nan, 'Bug'), (nan, 'Bug'), ('Flying', 'Bug'),
#        ('Normal', 'Fire'), ('Normal', 'Fire'), (nan, 'Fairy'),
#        (nan, 'Fairy'), (nan, 'Fairy'), (nan, 'Grass'), (nan, 'Grass'),
#        (nan, 'Fighting'), ('Dark', 'Fighting'), ('Normal', nan),
#        (nan, 'Psychic'), (nan, 'Psychic'), (nan, 'Psychic'),
#        ('Ghost', 'Steel'), ('Ghost', 'Steel'), ('Ghost', 'Steel'),
#        ('Ghost', 'Steel'), (nan, 'Fairy'), (nan, 'Fairy'), (nan, 'Fairy'),
#        (nan, 'Fairy'), ('Dark', 'Psychic'), ('Dark', 'Psychic'),
#        ('Rock', 'Water'), ('Rock', 'Water'), ('Poison', 'Water'),
#        ('Dragon', 'Poison'), (nan, 'Water'), (nan, 'Water'),
#        ('Normal', 'Electric'), ('Normal', 'Electric'), ('Dragon', 'Rock'),
#        ('Dragon', 'Rock'), ('Ice', 'Rock'), ('Ice', 'Rock'),
#        (nan, 'Fairy'), ('Flying', 'Fighting'), ('Electric', 'Fairy'),
#        ('Fairy', 'Rock'), (nan, 'Dragon'), (nan, 'Dragon'),
#        (nan, 'Dragon'), ('Fairy', 'Steel'), ('Ghost', 'Grass'),
#        ('Ghost', 'Grass'), ('Ghost', 'Grass'), ('Ghost', 'Grass'),
#        ('Ghost', 'Grass'), ('Ghost', 'Grass'), ('Ghost', 'Grass'),
#        ('Ghost', 'Grass'), ('Ghost', 'Grass'), ('Ghost', 'Grass'),
#        (nan, 'Ice'), (nan, 'Ice'), ('Flying', 'Dragon'),
#        ('Flying', 'Dragon'), (nan, 'Fairy'), ('Dark', 'Flying'),
#        ('Dragon', 'Ground'), ('Fairy', 'Rock'), ('Fairy', 'Rock'),
#        ('Ghost', 'Psychic'), ('Dark', 'Psychic'), ('Fire', 'Water')],
#       dtype=object)

# %%
pokemon[['t1','t2']].applymap(str).apply(lambda x : {'nan'} if (x.t1=='nan')&(x.t2=='nan') else 
                          (x.t1) if (x.t1!='nan')&(x.t2=='nan') else
                          (x.t2) if (x.t1=='nan')&(x.t2!='nan') else 
                          sorted ((x.t1,x.t2)),axis=1)
# Out:
# 0       [Grass, Poison]
# 1       [Grass, Poison]
# 2       [Grass, Poison]
# 3       [Grass, Poison]
# 4                  Fire
#              ...
# 795       [Fairy, Rock]
# 796       [Fairy, Rock]
# 797    [Ghost, Psychic]
# 798     [Dark, Psychic]
# 799       [Fire, Water]
# Length: 800, dtype: object

# %%
set(pokemon.t1.to_list()+pokemon.t1.to_list())
# Out:
# {'Bug',
#  'Dark',
#  'Dragon',
#  'Electric',
#  'Fairy',
#  'Fighting',
#  'Fire',
#  'Flying',
#  'Ghost',
#  'Grass',
#  'Ground',
#  'Ice',
#  'Normal',
#  'Poison',
#  'Psychic',
#  'Rock',
#  'Steel',
#  'Water'}

# %%
#Alternative too long
set(pokemon.t1).union(set(pokemon.t2))
# Out:
# {'Bug',
#  'Dark',
#  'Dragon',
#  'Electric',
#  'Fairy',
#  'Fighting',
#  'Fire',
#  'Flying',
#  'Ghost',
#  'Grass',
#  'Ground',
#  'Ice',
#  'Normal',
#  'Poison',
#  'Psychic',
#  'Rock',
#  'Steel',
#  'Water',
#  nan}

# %%
pd.unique(pokemon[['t1','t2']].values.ravel())
# Out:
# array(['Grass', 'Poison', 'Fire', nan, 'Flying', 'Dragon', 'Water', 'Bug',
#        'Normal', 'Electric', 'Ground', 'Fairy', 'Fighting', 'Psychic',
#        'Rock', 'Steel', 'Ice', 'Ghost', 'Dark'], dtype=object)

# %% [markdown]
# #### Cleanup `Name` that contain "Mega".
#
# If you have checked out the pokemon names carefully enough, you should have found there are junk texts in the pokemon names which contain "Mega". We want to clean up the pokemon names. For instance, "VenusaurMega Venusaur" should be "Mega Venusaur", and "CharizardMega Charizard X" should be "Mega Charizard X".

# %%
# your code here
#df['Desired'] = df['Current'].str.replace(r'\b(\w+)(\s+\1)+\b', r'\1')

import re 

pokemon['Name'] = pokemon['Name'].str.replace('.+?(?=Mega)', '')

# test transformed data
pokemon.head(10)
# Out:
#    #              Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  \
# 0  1         Bulbasaur  Grass  Poison    318  45      49       49       65
# 1  2           Ivysaur  Grass  Poison    405  60      62       63       80
# 2  3          Venusaur  Grass  Poison    525  80      82       83      100
# 3  3     Mega Venusaur  Grass  Poison    625  80     100      123      122
# 4  4        Charmander   Fire     NaN    309  39      52       43       60
# 5  5        Charmeleon   Fire     NaN    405  58      64       58       80
# 6  6         Charizard   Fire  Flying    534  78      84       78      109
# 7  6  Mega Charizard X   Fire  Dragon    634  78     130      111      130
# 8  6  Mega Charizard Y   Fire  Flying    634  78     104       78      159
# 9  7          Squirtle  Water     NaN    314  44      48       65       50
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False
# 5       65     80           1      False
# 6       85    100           1      False
# 7       85    100           1      False
# 8      115    100           1      False
# 9       64     43           1      False

# %%
pokemon.Name.str.split().apply(lambda x: 'Mega ' + x[1-1] if len(x)>1 else x[1-1])
# Out:
# 0              Bulbasaur
# 1                Ivysaur
# 2               Venusaur
# 3      Mega VenusaurMega
# 4             Charmander
#              ...
# 795              Diancie
# 796     Mega DiancieMega
# 797      Mega HoopaHoopa
# 798      Mega HoopaHoopa
# 799            Volcanion
# Name: Name, Length: 800, dtype: object

# %% [markdown]
# #### Create a new column called `A/D Ratio` whose value equals to `Attack` devided by `Defense`.
#
# For instance, if a pokemon has the Attack score 49 and Defense score 49, the corresponding `A/D Ratio` is 49/49=1.

# %%
# your code here
pokemon['A/D Ratio'] = pokemon['Attack'] / pokemon['Defense']
pokemon.head()
# Out:
#    #                   Name     t1      t2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary  A/D Ratio
# 0       65       65     45           1      False   1.000000
# 1       80       80     60           1      False   0.984127
# 2      100      100     80           1      False   0.987952
# 3      122      120     80           1      False   0.813008
# 4       60       50     65           1      False   1.209302

# %% [markdown]
# #### Identify the pokemon with the highest `A/D Ratio`.

# %%
# your code here

pokemon.loc[pokemon['A/D Ratio'] == pokemon['A/D Ratio'].max()]
# Out:
#        #                Name       t1   t2  Total  HP  Attack  Defense  \
# 429  386  DeoxysAttack Forme  Psychic  NaN    600  50     180       20
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary  A/D Ratio
# 429      180       20    150           3       True        9.0

# %%
pokemon.loc[pokemon['A/D Ratio'].idxmax()]
# Out:
# #                            386
# Name          DeoxysAttack Forme
# t1                       Psychic
# t2                           NaN
# Total                        600
# HP                            50
# Attack                       180
# Defense                       20
# Sp. Atk                      180
# Sp. Def                       20
# Speed                        150
# Generation                     3
# Legendary                   True
# A/D Ratio                      9
# Name: 429, dtype: object

# %% [markdown]
# #### Identify the pokemon with the lowest A/D Ratio.

# %%
# your code here

pokemon.loc[pokemon['A/D Ratio'] == pokemon['A/D Ratio'].min()]
# Out:
#        #     Name Type 1 Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 230  213  Shuckle    Bug   Rock    505  20      10      230       10      230
#
#      Speed  Generation  Legendary  A/D Ratio
# 230      5           2      False   0.043478

# %% [markdown]
# #### Create a new column called `Combo Type` whose value combines `Type 1` and `Type 2`.
#
# Rules:
#
# * If both `Type 1` and `Type 2` have valid values, the `Combo Type` value should contain both values in the form of `<Type 1> <Type 2>`. For example, if `Type 1` value is `Grass` and `Type 2` value is `Poison`, `Combo Type` will be `Grass-Poison`.
#
# * If `Type 1` has valid value but `Type 2` is not, `Combo Type` will be the same as `Type 1`. For example, if `Type 1` is `Fire` whereas `Type 2` is `NaN`, `Combo Type` will be `Fire`.

# %%
# your code here

#pokemon['Combo Type'] = lambda combo_type : pokemon['Type 1'] + '-' + pokemon['Type 2'] if pokemon.notna(pokemon['Type 1']) and pokemon.notna(pokemon['Type 2']) else (pokemon['Type 1'] if pokemon.notna(pokemon['Type 1']) else pokemon['Type 2'])

#pokemon['Combo Type'].apply(lambda combo_type : pokemon['Type 1'] + '-' + pokemon['Type 2'] if pokemon.notna(pokemon['Type 1']) and pokemon.notna(pokemon['Type 2']) else 'lol')

pokemon['Type 1'] = pokemon['Type 1'].fillna(" ")
pokemon['Type 2'] = pokemon['Type 2'].fillna(" ")

pokemon['Combo Type'] = pokemon['Type 1'] + '-' + pokemon['Type 2']

pokemon.head(25)

#lambda x: x*10 if x<2 else (x**2 if x<4 else x+10)
# Out:
#      #              Name  Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  \
# 0    1         Bulbasaur   Grass  Poison    318  45      49       49       65
# 1    2           Ivysaur   Grass  Poison    405  60      62       63       80
# 2    3          Venusaur   Grass  Poison    525  80      82       83      100
# 3    3     Mega Venusaur   Grass  Poison    625  80     100      123      122
# 4    4        Charmander    Fire            309  39      52       43       60
# 5    5        Charmeleon    Fire            405  58      64       58       80
# 6    6         Charizard    Fire  Flying    534  78      84       78      109
# 7    6  Mega Charizard X    Fire  Dragon    634  78     130      111      130
# 8    6  Mega Charizard Y    Fire  Flying    634  78     104       78      159
# 9    7          Squirtle   Water            314  44      48       65       50
# 10   8         Wartortle   Water            405  59      63       80       65
# 11   9         Blastoise   Water            530  79      83      100       85
# 12   9    Mega Blastoise   Water            630  79     103      120      135
# 13  10          Caterpie     Bug            195  45      30       35       20
# 14  11           Metapod     Bug            205  50      20       55       25
# 15  12        Butterfree     Bug  Flying    395  60      45       50       90
# 16  13            Weedle     Bug  Poison    195  40      35       30       20
# 17  14            Kakuna     Bug  Poison    205  45      25       50       25
# 18  15          Beedrill     Bug  Poison    395  65      90       40       45
# 19  15     Mega Beedrill     Bug  Poison    495  65     150       40       15
# 20  16            Pidgey  Normal  Flying    251  40      45       40       35
# 21  17         Pidgeotto  Normal  Flying    349  63      60       55       50
# 22  18           Pidgeot  Normal  Flying    479  83      80       75       70
# 23  18      Mega Pidgeot  Normal  Flying    579  83      80       80      135
# 24  19           Rattata  Normal            253  30      56       35       25
#
#     Sp. Def  Speed  Generation  Legendary  A/D Ratio     Combo Type
# 0        65     45           1      False   1.000000   Grass-Poison
# 1        80     60           1      False   0.984127   Grass-Poison
# 2       100     80           1      False   0.987952   Grass-Poison
# 3       120     80           1      False   0.813008   Grass-Poison
# 4        50     65           1      False   1.209302         Fire-
# 5        65     80           1      False   1.103448         Fire-
# 6        85    100           1      False   1.076923    Fire-Flying
# 7        85    100           1      False   1.171171    Fire-Dragon
# 8       115    100           1      False   1.333333    Fire-Flying
# 9        64     43           1      False   0.738462        Water-
# 10       80     58           1      False   0.787500        Water-
# 11      105     78           1      False   0.830000        Water-
# 12      115     78           1      False   0.858333        Water-
# 13       20     45           1      False   0.857143          Bug-
# 14       25     30           1      False   0.363636          Bug-
# 15       80     70           1      False   0.900000     Bug-Flying
# 16       20     50           1      False   1.166667     Bug-Poison
# 17       25     35           1      False   0.500000     Bug-Poison
# 18       80     75           1      False   2.250000     Bug-Poison
# 19       80    145           1      False   3.750000     Bug-Poison
# 20       35     56           1      False   1.125000  Normal-Flying
# 21       50     71           1      False   1.090909  Normal-Flying
# 22       70    101           1      False   1.066667  Normal-Flying
# 23       80    121           1      False   1.000000  Normal-Flying
# 24       35     72           1      False   1.600000       Normal-

# %% [markdown]
# #### Identify the pokemon whose `A/D Ratio` are among the top 5.

# %%
# your code here

top_5 = pokemon.nlargest(5, 'A/D Ratio')
top_5
# Out:
#        #                Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 429  386  DeoxysAttack Forme  Psychic            600  50     180       20
# 347  318            Carvanha    Water    Dark    305  45      90       20
# 19    15       Mega Beedrill      Bug  Poison    495  65     150       40
# 453  408            Cranidos     Rock            350  67     125       40
# 348  319            Sharpedo    Water    Dark    460  70     120       40
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary  A/D Ratio  Combo Type
# 429      180       20    150           3       True      9.000   Psychic-
# 347       65       20     65           3      False      4.500  Water-Dark
# 19        15       80    145           1      False      3.750  Bug-Poison
# 453       30       30     58           4      False      3.125      Rock-
# 348       95       40     95           3      False      3.000  Water-Dark

# %% [markdown]
# #### For the 5 pokemon printed above, aggregate `Combo Type` and use a list to store the unique values.
#
# Your end product is a list containing the distinct `Combo Type` values of the 5 pokemon with the highest `A/D Ratio`.

# %%
# your code here
lst_unique = list(top_5['Combo Type'].unique())

lst_unique
# Out:
# ['Psychic- ', 'Water-Dark', 'Bug-Poison', 'Rock- ']

# %% [markdown]
# #### For each of the `Combo Type` values obtained from the previous question, calculate the mean scores of all numeric fields across all pokemon.
#
# Your output should look like below:
#
# ![Aggregate](../images/aggregated-mean.png)

# %%
# your code here
pokemon = pokemon[pokemon['Combo Type'].isin(lst_unique)]
pokemon.groupby('Combo Type').agg('mean')
# Out:
#                      #       Total         HP      Attack     Defense  \
# Combo Type
# Bug-Poison  199.166667  347.916667  53.750000   68.333333   58.083333
# Psychic-    381.973684  464.552632  72.552632   64.947368   67.236842
# Rock-       410.111111  409.444444  67.111111  103.333333  107.222222
# Water-Dark  347.666667  493.833333  69.166667  120.000000   65.166667
#
#               Sp. Atk    Sp. Def      Speed  Generation  Legendary  A/D Ratio
# Combo Type
# Bug-Poison  42.500000  59.333333  65.916667    2.333333   0.000000   1.315989
# Psychic-    98.552632  82.394737  78.868421    3.342105   0.236842   1.164196
# Rock-       40.555556  58.333333  32.888889    3.888889   0.111111   1.260091
# Water-Dark  88.833333  63.500000  87.166667    3.166667   0.000000   2.291949
