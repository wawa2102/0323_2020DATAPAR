# %% [markdown]
# # Web Scraping Lab
#
# You will find in this notebook some scrapy exercises to practise your scraping skills.
#
# **Tips:**
#
# - Check the response status code for each request to ensure you have obtained the intended content.
# - Print the response text in each request to understand the kind of info you are getting and its format.
# - Check for patterns in the response text to extract the data/info requested in each question.
# - Visit the urls below and take a look at their source code through Chrome DevTools. You'll need to identify the html tags, special class names, etc used in the html content you are expected to extract.
#
# **Resources**:
# - [Requests library](http://docs.python-requests.org/en/master/#the-user-guide)
# - [Beautiful Soup Doc](https://www.crummy.com/software/BeautifulSoup/bs4/doc/)
# - [Urllib](https://docs.python.org/3/library/urllib.html#module-urllib)
# - [re lib](https://docs.python.org/3/library/re.html)
# - [lxml lib](https://lxml.de/)
# - [Scrapy](https://scrapy.org/)
# - [List of HTTP status codes](https://en.wikipedia.org/wiki/List_of_HTTP_status_codes)
# - [HTML basics](http://www.simplehtmlguide.com/cheatsheet.php)
# - [CSS basics](https://www.cssbasics.com/#page_start)

# %% [markdown]
# #### Below are the libraries and modules you may need. `requests`,  `BeautifulSoup` and `pandas` are already imported for you. If you prefer to use additional libraries feel free to do it.

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %% [markdown]
# #### Download, parse (using BeautifulSoup), and print the content from the Trending Developers page from GitHub:

# %%
# This is the url you will scrape in this exercise
url ='https://github.com/trending/developers'

# %%
# your code here
html=requests.get(url).content

# %%
soup=BeautifulSoup(html)

# %%
#Method 1
[f"{i.text.strip()} ({i['href'].lstrip('/')})" for i in soup.select('h1.h3>a')]
# Out:
# ['Jeremy Apthorp (nornagon)',
#  'Jonah Williams (jonahwilliams)',
#  'Felix Angelov (felangel)',
#  'chencheng (云谦) (sorrycc)',
#  'Sebastián Ramírez (tiangolo)',
#  'Mariusz Nowak (medikoo)',
#  'Dawid Urbaniak (Trancever)',
#  'Jeffrey Su (JeffreySu)',
#  'Hugo Bowne-Anderson (hugobowne)',
#  'Felipe Fialho (felipefialho)',
#  'Yuri Shkuro (yurishkuro)',
#  'R.I.Pienaar (ripienaar)',
#  'Zeno Rocha (zenorocha)',
#  'Maxim Kulkin (maximkulkin)',
#  'Robert Mosolgo (rmosolgo)',
#  'Pierre Krieger (tomaka)',
#  'Iman (imanghafoori1)',
#  'Luis Alvarez D. (lfades)',
#  'Matic Zavadlal (maticzav)',
#  'Marten Seemann (marten-seemann)',
#  'David Peter (sharkdp)',
#  'Jake Wharton (JakeWharton)',
#  'Jeff Bezanson (JeffBezanson)',
#  'James Munnelly (munnerz)',
#  'Matthew Johnson (mattjj)']

# %%
#Method 2
texts = [i.text.strip() for i in soup.select('h1.h3,p.f4>a')]
[(texts[i],texts[i+1]) for i in range(0,len(texts),2)]

# %% [markdown]
# #### Display the names of the trending developers retrieved in the previous step.
#
# Your output should be a Python list of developer names. Each name should not contain any html tag.
#
# **Instructions:**
#
# 1. Find out the html tag and class names used for the developer names. You can achieve this using Chrome DevTools.
#
# 1. Use BeautifulSoup to extract all the html elements that contain the developer names.
#
# 1. Use string manipulation techniques to replace whitespaces and linebreaks (i.e. `\n`) in the *text* of each html element. Use a list to store the clean names.
#
# 1. Print the list of names.
#
# Your output should look like below:
#
# ```
# ['trimstray (@trimstray)',
#  'joewalnes (JoeWalnes)',
#  'charlax (Charles-AxelDein)',
#  'ForrestKnight (ForrestKnight)',
#  'revery-ui (revery-ui)',
#  'alibaba (Alibaba)',
#  'Microsoft (Microsoft)',
#  'github (GitHub)',
#  'facebook (Facebook)',
#  'boazsegev (Bo)',
#  'google (Google)',
#  'cloudfetch',
#  'sindresorhus (SindreSorhus)',
#  'tensorflow',
#  'apache (TheApacheSoftwareFoundation)',
#  'DevonCrawford (DevonCrawford)',
#  'ARMmbed (ArmMbed)',
#  'vuejs (vuejs)',
#  'fastai (fast.ai)',
#  'QiShaoXuan (Qi)',
#  'joelparkerhenderson (JoelParkerHenderson)',
#  'torvalds (LinusTorvalds)',
#  'CyC2018',
#  'komeiji-satori (神楽坂覚々)',
#  'script-8']
#  ```

# %%
# your code here

# %% [markdown]
# #### Display the trending Python repositories in GitHub.
#
# The steps to solve this problem is similar to the previous one except that you need to find out the repository names instead of developer names.

# %%
# This is the url you will scrape in this exercise
url = 'https://github.com/trending/python?since=daily'

# %%
# your code here
html=requests.get(url).content
soup=BeautifulSoup(html)

[i.text.strip().split()[2] for i in soup.select('h1.h3>a')]
# Out:
# ['pluradl.py',
#  'SReC',
#  'interview_internal_reference',
#  'face_recognition',
#  'skillbox-async-chat',
#  'deocclusion',
#  'text-to-text-transfer-transformer',
#  'GitHub-Chinese-Top-Charts',
#  'fastapi',
#  'Real-Time-Voice-Cloning',
#  'core',
#  'ObstructionRemoval',
#  'Whole-Foods-Delivery-Slot',
#  'Games',
#  'doccano',
#  'jax',
#  'HanLP',
#  'pygta5',
#  'ray',
#  'elastalert',
#  'InstaPy',
#  'transformers',
#  'Self-Driving-Car-in-Video-Games',
#  'keras-retinanet',
#  'airflow']

# %% [markdown]
# #### Display all the image links from Walt Disney wikipedia page.

# %%
# This is the url you will scrape in this exercise
url = 'https://en.wikipedia.org/wiki/Walt_Disney'

# %%
# your code here
html=requests.get(url).content
soup=BeautifulSoup(html)
[i['src'] for i in soup.select('img')]
# Out:
# ['//upload.wikimedia.org/wikipedia/en/thumb/e/e7/Cscr-featured.svg/20px-Cscr-featured.svg.png',
#  '//upload.wikimedia.org/wikipedia/en/thumb/1/1b/Semi-protection-shackle.svg/20px-Semi-protection-shackle.svg.png',
#  '//upload.wikimedia.org/wikipedia/commons/thumb/d/df/Walt_Disney_1946.JPG/220px-Walt_Disney_1946.JPG',
#  '//upload.wikimedia.org/wikipedia/commons/thumb/8/87/Walt_Disney_1942_signature.svg/150px-Walt_Disney_1942_signature.svg.png',
#  '//upload.wikimedia.org/wikipedia/commons/thumb/c/c4/Walt_Disney_envelope_ca._1921.jpg/220px-Walt_Disney_envelope_ca._1921.jpg',
#  '//upload.wikimedia.org/wikipedia/commons/thumb/4/4d/Newman_Laugh-O-Gram_%281921%29.webm/220px-seek%3D2-Newman_Laugh-O-Gram_%281921%29.webm.jpg',
#  '//upload.wikimedia.org/wikipedia/commons/thumb/0/0d/Trolley_Troubles_poster.jpg/170px-Trolley_Troubles_poster.jpg',
#  '//upload.wikimedia.org/wikipedia/commons/thumb/7/71/Walt_Disney_and_his_cartoon_creation_%22Mickey_Mouse%22_-_National_Board_of_Review_Magazine.jpg/170px-Walt_Disney_and_his_cartoon_creation_%22Mickey_Mouse%22_-_National_Board_of_Review_Magazine.jpg',
#  '//upload.wikimedia.org/wikipedia/en/thumb/4/4e/Steamboat-willie.jpg/170px-Steamboat-willie.jpg',
#  '//upload.wikimedia.org/wikipedia/commons/thumb/5/57/Walt_Disney_1935.jpg/170px-Walt_Disney_1935.jpg',
#  '//upload.wikimedia.org/wikipedia/commons/thumb/c/cd/Walt_Disney_Snow_white_1937_trailer_screenshot_%2813%29.jpg/220px-Walt_Disney_Snow_white_1937_trailer_screenshot_%2813%29.jpg',
#  '//upload.wikimedia.org/wikipedia/commons/thumb/1/15/Disney_drawing_goofy.jpg/170px-Disney_drawing_goofy.jpg',
#  '//upload.wikimedia.org/wikipedia/commons/thumb/1/13/DisneySchiphol1951.jpg/220px-DisneySchiphol1951.jpg',
#  '//upload.wikimedia.org/wikipedia/commons/thumb/8/8c/WaltDisneyplansDisneylandDec1954.jpg/220px-WaltDisneyplansDisneylandDec1954.jpg',
#  '//upload.wikimedia.org/wikipedia/commons/thumb/f/ff/Walt_disney_portrait_right.jpg/170px-Walt_disney_portrait_right.jpg',
#  '//upload.wikimedia.org/wikipedia/commons/thumb/1/1a/Walt_Disney_Grave.JPG/170px-Walt_Disney_Grave.JPG',
#  '//upload.wikimedia.org/wikipedia/commons/thumb/2/2d/Roy_O._Disney_with_Company_at_Press_Conference.jpg/170px-Roy_O._Disney_with_Company_at_Press_Conference.jpg',
#  '//upload.wikimedia.org/wikipedia/commons/thumb/a/a9/Disney_Display_Case.JPG/170px-Disney_Display_Case.JPG',
#  '//upload.wikimedia.org/wikipedia/commons/thumb/6/6c/Disney1968.jpg/170px-Disney1968.jpg',
#  '//upload.wikimedia.org/wikipedia/en/thumb/8/8a/OOjs_UI_icon_edit-ltr-progressive.svg/10px-OOjs_UI_icon_edit-ltr-progressive.svg.png',
#  '//upload.wikimedia.org/wikipedia/commons/thumb/4/44/The_Walt_Disney_Company_Logo.svg/120px-The_Walt_Disney_Company_Logo.svg.png',
#  '//upload.wikimedia.org/wikipedia/commons/thumb/d/da/Animation_disc.svg/30px-Animation_disc.svg.png',
#  '//upload.wikimedia.org/wikipedia/en/thumb/6/69/P_vip.svg/29px-P_vip.svg.png',
#  '//upload.wikimedia.org/wikipedia/commons/thumb/1/1a/Magic_Kingdom_castle.jpg/24px-Magic_Kingdom_castle.jpg',
#  '//upload.wikimedia.org/wikipedia/en/thumb/e/e7/Video-x-generic.svg/30px-Video-x-generic.svg.png',
#  '//upload.wikimedia.org/wikipedia/commons/thumb/a/a3/Flag_of_Los_Angeles_County%2C_California.svg/30px-Flag_of_Los_Angeles_County%2C_California.svg.png',
#  '//upload.wikimedia.org/wikipedia/commons/thumb/8/8c/Blank_television_set.svg/30px-Blank_television_set.svg.png',
#  '//upload.wikimedia.org/wikipedia/en/thumb/a/a4/Flag_of_the_United_States.svg/30px-Flag_of_the_United_States.svg.png',
#  '//upload.wikimedia.org/wikipedia/en/thumb/4/4a/Commons-logo.svg/22px-Commons-logo.svg.png',
#  '//upload.wikimedia.org/wikipedia/commons/thumb/f/fa/Wikiquote-logo.svg/25px-Wikiquote-logo.svg.png',
#  '//upload.wikimedia.org/wikipedia/commons/thumb/f/ff/Wikidata-logo.svg/30px-Wikidata-logo.svg.png',
#  '//upload.wikimedia.org/wikipedia/en/thumb/8/8a/OOjs_UI_icon_edit-ltr-progressive.svg/10px-OOjs_UI_icon_edit-ltr-progressive.svg.png',
#  '//en.wikipedia.org/wiki/Special:CentralAutoLogin/start?type=1x1',
#  '/static/images/wikimedia-button.png',
#  '/static/images/poweredby_mediawiki_88x31.png']

# %% [markdown]
# #### Retrieve an arbitary Wikipedia page of "Python" and create a list of links on that page.

# %%
# This is the url you will scrape in this exercise
url ='https://en.wikipedia.org/wiki/Python'

# %%
# your code here
#.mw-parser-output li>a

html=requests.get(url).content
soup=BeautifulSoup(html)
all = [i['href'] for i in soup.select('.mw-parser-output li>a')]
all
# Out:
# ['#Snakes',
#  '#Ancient_Greece',
#  '#Media_and_entertainment',
#  '#Computing',
#  '#Engineering',
#  '#Roller_coasters',
#  '#Vehicles',
#  '#Weaponry',
#  '#People',
#  '#Other_uses',
#  '#See_also',
#  '/wiki/Pythonidae',
#  '/wiki/Python_(genus)',
#  '/wiki/Python_(mythology)',
#  '/wiki/Python_of_Aenus',
#  '/wiki/Python_(painter)',
#  '/wiki/Python_of_Byzantium',
#  '/wiki/Python_of_Catana',
#  '/wiki/Python_(film)',
#  '/wiki/Monty_Python',
#  '/wiki/Python_(Monty)_Pictures',
#  '/wiki/Python_(programming_language)',
#  '/wiki/CPython',
#  '/wiki/CMU_Common_Lisp',
#  '/wiki/PERQ#PERQ_3',
#  '/wiki/Python_(Busch_Gardens_Tampa_Bay)',
#  '/wiki/Python_(Coney_Island,_Cincinnati,_Ohio)',
#  '/wiki/Python_(Efteling)',
#  '/wiki/Python_(automobile_maker)',
#  '/wiki/Python_(Ford_prototype)',
#  '/wiki/Colt_Python',
#  '/wiki/Python_(missile)',
#  '/wiki/Python_(nuclear_primary)',
#  '/wiki/Python_Anghelo',
#  '/wiki/PYTHON',
#  '/wiki/Cython']

# %%
import random
all_mini = []

for i in range(11,len(all)):
    all_mini.append(all[i])
all_mini

url_2 ='https://en.wikipedia.org'+all_mini[random.randint(0,25)]
url_2
# Out:
# 'https://en.wikipedia.org/wiki/Python_(nuclear_primary)'

# %%
html=requests.get(url_2).content
soup=BeautifulSoup(html)
all = [i for i in soup.select('a')]
all
# Out:
# [<a id="top"></a>,
#  <a class="mw-jump-link" href="#mw-head">Jump to navigation</a>,
#  <a class="mw-jump-link" href="#p-search">Jump to search</a>,
#  <a href="/wiki/Chuck_Hansen" title="Chuck Hansen">Chuck Hansen</a>,
#  <a href="/wiki/Nuclear_weapon_design#Two-stage_thermonuclear_weapons" title="Nuclear weapon design">primary</a>,
#  <a href="/wiki/Thermonuclear_weapon" title="Thermonuclear weapon">thermonuclear weapons</a>,
#  <a class="mw-redirect" href="/wiki/W34_(nuclear_bomb)" title="W34 (nuclear bomb)">W34</a>,
#  <a href="/wiki/B28_nuclear_bomb" title="B28 nuclear bomb">B28 nuclear bomb</a>,
#  <a class="mw-redirect" href="/wiki/W28" title="W28">W28</a>,
#  <a href="/wiki/W40_(nuclear_warhead)" title="W40 (nuclear warhead)">W40</a>,
#  <a href="/wiki/W49" title="W49">W49</a>,
#  <a href="/wiki/Mark_45_torpedo" title="Mark 45 torpedo">Mark 45 ASTOR</a>,
#  <a href="/wiki/Nuclear_depth_bomb" title="Nuclear depth bomb">nuclear depth bomb</a>,
#  <a class="mw-redirect" href="/wiki/W34_(nuclear_bomb)" title="W34 (nuclear bomb)">W34</a>,
#  <a href="/wiki/Red_Snow" title="Red Snow">Red Snow</a>,
#  <a class="mw-redirect" href="/wiki/W28" title="W28">W28</a>,
#  <a href="/wiki/Red_Beard_(nuclear_weapon)" title="Red Beard (nuclear weapon)">Red Beard</a>,
#  <a class="new" href="/w/index.php?title=Violet_Mist&amp;action=edit&amp;redlink=1" title="Violet Mist (page does not exist)">Violet Mist</a>,
#  <a class="mw-redirect" href="/wiki/Nuclear_land_mine" title="Nuclear land mine">nuclear land mine</a>,
#  <a class="mw-redirect" href="/wiki/High_explosive" title="High explosive">high explosive</a>,
#  <a href="/wiki/Octol" title="Octol">Octol</a>,
#  <a href="/wiki/HMX" title="HMX">HMX</a>,
#  <a href="/wiki/TNT" title="TNT">TNT</a>,
#  <a href="/wiki/Polymer-bonded_explosive" title="Polymer-bonded explosive">PBX</a>,
#  <a href="/wiki/AIR-2_Genie" title="AIR-2 Genie">AIR-2 Genie</a>,
#  <a href="/wiki/Air-to-air_rocket" title="Air-to-air rocket">air-to-air rocket</a>,
a class="interlanguage-link-target" href="https://fr.wikipedia.org/wiki/Primaire_nucl%C3%A9aire_Python" hreflang="fr" lang="fr" title="Primaire nucléaire Python – French">Français</a>,
#  <a class="interlanguage-link-target" href="https://ja.wikipedia.org/wiki/%E3%83%91%E3%82%A4%E3%82%BD%E3%83%B3_(%E6%A0%B8%E5%85%B5%E5%99%A8%E3%83%97%E3%83%A9%E3%82%A4%E3%83%9E%E3%83%AA)" hreflang="ja" lang="ja" title="パイソン (核兵器プライマリ) – Japanese">日本語</a>,
#  <a class="interlanguage-link-target" href="https://pt.wikipedia.org/wiki/Python_Prim%C3%A1rio" hreflang="pt" lang="pt" title="Python Primário – Portuguese">Português</a>,
#  <a class="wbc-editpage" href="https://www.wikidata.org/wiki/Special:EntityPage/Q7263939#sitelinks-wikipedia" title="Edit interlanguage links">Edit links</a>,
#  <a href="//en.wikipedia.org/wiki/Wikipedia:Text_of_Creative_Commons_Attribution-ShareAlike_3.0_Unported_License" rel="license">Creative Commons Attribution-ShareAlike License</a>,
#  <a href="//creativecommons.org/licenses/by-sa/3.0/" rel="license" style="display:none;"></a>,
#  <a href="//foundation.wikimedia.org/wiki/Terms_of_Use">Terms of Use</a>,
#  <a href="//foundation.wikimedia.org/wiki/Privacy_policy">Privacy Policy</a>,
#  <a href="//www.wikimediafoundation.org/">Wikimedia Foundation, Inc.</a>,
#  <a class="extiw" href="https://foundation.wikimedia.org/wiki/Privacy_policy" title="wmf:Privacy policy">Privacy policy</a>,
#  <a href="/wiki/Wikipedia:About" title="Wikipedia:About">About Wikipedia</a>,
#  <a href="/wiki/Wikipedia:General_disclaimer" title="Wikipedia:General disclaimer">Disclaimers</a>,
#  <a href="//en.wikipedia.org/wiki/Wikipedia:Contact_us">Contact Wikipedia</a>,
#  <a href="https://www.mediawiki.org/wiki/Special:MyLanguage/How_to_contribute">Developers</a>,
#  <a href="https://stats.wikimedia.org/#/en.wikipedia.org">Statistics</a>,
#  <a href="https://foundation.wikimedia.org/wiki/Cookie_statement">Cookie statement</a>,
#  <a class="noprint stopMobileRedirectToggle" href="//en.m.wikipedia.org/w/index.php?title=Python_(nuclear_primary)&amp;mobileaction=toggle_view_mobile">Mobile view</a>,
#  <a href="https://wikimediafoundation.org/"><img alt="Wikimedia Foundation" height="31" src="/static/images/wikimedia-button.png" srcset="/static/images/wikimedia-button-1.5x.png 1.5x, /static/images/wikimedia-button-2x.png 2x" width="88"/></a>,
#  <a href="https://www.mediawiki.org/"><img alt="Powered by MediaWiki" height="31" src="/static/images/poweredby_mediawiki_88x31.png" srcset="/static/images/poweredby_mediawiki_132x47.png 1.5x, /static/images/poweredby_mediawiki_176x62.png 2x" width="88"/></a>]

# %% [markdown]
# #### Find the number of titles that have changed in the United States Code since its last release point.

# %%
# This is the url you will scrape in this exercise
url = 'http://uscode.house.gov/download/download.shtml'

# %%
# your code here
#.usctitlechanged

html=requests.get(url).content
soup=BeautifulSoup(html)
all = [i.text.strip() for i in soup.select('.usctitlechanged')]
all
# Out:
# ['Title 8 - Aliens and Nationality',
#  'Title 22 - Foreign Relations and Intercourse',
#  'Title 29 - Labor',
#  'Title 42 - The Public Health and Welfare']

# %% [markdown]
# #### Find a Python list with the top ten FBI's Most Wanted names.

# %%
# This is the url you will scrape in this exercise
url = 'https://www.fbi.gov/wanted/topten'

# %%
# your code here
url_fbi = 'https://www.fbi.gov/wanted/topten'
html_fbi = r.get(url_fbi).content
soup_fbi = BeautifulSoup(html_fbi)
[tt.text.strip() for tt in soup_fbi.select('h3')]

# %% [markdown]
# ####  Display the 20 latest earthquakes info (date, time, latitude, longitude and region name) by the EMSC as a pandas dataframe.

# %%
# This is the url you will scrape in this exercise
url = 'https://www.emsc-csem.org/Earthquake/'

# %%
# your code here

html=requests.get(url).content
soup=BeautifulSoup(html)
all = [i.text.strip().split('\xa0') for i in soup.select('tr.normal')][:20]
all
pd.DataFrame(all,columns=all[0])
# Out:
#     earthquake2020-04-09           12:40:20.028min ago9.33  S    113.08  E    \
# 0   earthquake2020-04-09           12:40:20.028min ago9.33  S    113.08  E
# 1   earthquake2020-04-09          12:29:41.039min ago45.79  N     14.79  E
# 2   earthquake2020-04-09           12:26:50.042min ago1.37  N    120.34  E
# 3   earthquake2020-04-09          12:20:36.248min ago24.86  N     45.90  W
# 4   earthquake2020-04-09          12:11:18.157min ago13.25  N     87.73  W
# 5   earthquake2020-04-09           12:09:01.059min ago2.88  S    119.42  E
# 6   earthquake2020-04-09      12:05:25.61hr 03min ago48.19  N      4.41  W
# 7   earthquake2020-04-09      11:47:07.01hr 21min ago51.54  N     16.16  E
# 8   earthquake2020-04-09       11:46:07.01hr 22min ago6.31  S    105.40  E
# 9   earthquake2020-04-09      11:24:38.91hr 44min ago19.22  N    155.43  W
# 10  earthquake2020-04-09      10:53:51.72hr 14min ago35.90  S    103.93  W
# 11  earthquake2020-04-09       10:51:56.02hr 16min ago2.13  S    140.08  E
# 12  earthquake2020-04-09       10:21:08.02hr 47min ago5.27  N     95.49  E
# 13  earthquake2020-04-09      10:15:29.02hr 53min ago19.61  N     69.65  W
# 14  earthquake2020-04-09       10:10:45.02hr 58min ago5.31  N     95.66  E
# 15  earthquake2020-04-09       10:08:30.03hr 00min ago1.67  S    120.21  E
# 16  earthquake2020-04-09       10:06:37.03hr 02min ago3.36  S    127.16  E
# 17  earthquake2020-04-09      09:54:23.53hr 14min ago17.95  N     66.81  W
# 18  earthquake2020-04-09       09:53:09.03hr 15min ago5.39  N     95.65  E
# 19  earthquake2020-04-09      09:43:58.83hr 24min ago24.18  S     67.02  W
#
#      10 M3.3          SOUTH OF JAVA, INDONESIA2020-04-09 12:50
# 0    10 M3.3          SOUTH OF JAVA, INDONESIA2020-04-09 12:50
# 1    30ML1.6                          SLOVENIA2020-04-09 12:40
# 2    10 M3.8     MINAHASA, SULAWESI, INDONESIA2020-04-09 12:31
# 3    10mb5.1       NORTHERN MID-ATLANTIC RIDGE2020-04-09 12:42
# 4   170mb4.6     GOLFO DE FONSECA, EL SALVADOR2020-04-09 12:29
# 5    10 M2.5               SULAWESI, INDONESIA2020-04-09 12:20
# 6     2ML2.6                            FRANCE2020-04-09 12:45
# 7     1ML2.5                            POLAND2020-04-09 11:54
# 8   118 M3.4           SUNDA STRAIT, INDONESIA2020-04-09 12:00
# 9    32Md2.2          ISLAND OF HAWAII, HAWAII2020-04-09 11:27
# 10   10mb5.0        SOUTHEAST OF EASTER ISLAND2020-04-09 12:44
# 11   10 M3.5  NEAR N COAST OF PAPUA, INDONESIA2020-04-09 11:20
# 12   10 M2.9       NORTHERN SUMATRA, INDONESIA2020-04-09 10:35
# 13   25 M3.2         DOMINICAN REPUBLIC REGION2020-04-09 12:05
# 14   12 M3.2       NORTHERN SUMATRA, INDONESIA2020-04-09 10:20
# 15   10 M4.2               SULAWESI, INDONESIA2020-04-09 10:20
# 16   68 M2.6                  SERAM, INDONESIA2020-04-09 10:11
# 17   10Md2.4                PUERTO RICO REGION2020-04-09 10:07
# 18   10 M3.9       NORTHERN SUMATRA, INDONESIA2020-04-09 10:05
# 19  166mb5.0                  SALTA, ARGENTINA2020-04-09 12:43

# %%
#Correction
#elements inside => contains
table = soup.select('table:contains("Longitude")')
first_column=soup.select('table td.tabev6')
first_column

#elements inside => has

# %%
table = soup.select('table:contains("Longitude")')[0]
[i.text.split() for i in table.select('td.tabev6 a')]
# Out:
# [['2020-04-09', '12:40:20.0'],
#  ['2020-04-09', '12:29:41.0'],
#  ['2020-04-09', '12:26:50.0'],
#  ['2020-04-09', '12:20:36.2'],
#  ['2020-04-09', '12:11:18.1'],
#  ['2020-04-09', '12:09:01.0'],
#  ['2020-04-09', '12:05:25.6'],
#  ['2020-04-09', '11:47:07.0'],
#  ['2020-04-09', '11:46:07.0'],
#  ['2020-04-09', '11:24:38.9'],
#  ['2020-04-09', '10:53:51.7'],
#  ['2020-04-09', '10:51:56.0'],
#  ['2020-04-09', '10:21:08.0'],
#  ['2020-04-09', '10:15:29.0'],
#  ['2020-04-09', '10:10:45.0'],
#  ['2020-04-09', '10:08:30.0'],
#  ['2020-04-09', '10:06:37.0'],
#  ['2020-04-09', '09:54:23.5'],
#  ['2020-04-09', '09:53:09.0'],
#  ['2020-04-09', '09:43:58.8'],
#  ['2020-04-09', '09:43:35.3'],
#  ['2020-04-09', '09:12:59.7'],
#  ['2020-04-09', '09:12:06.6'],
#  ['2020-04-09', '09:08:12.2'],
#  ['2020-04-09', '09:08:07.0'],
#  ['2020-04-09', '08:56:49.0'],
#  ['2020-04-09', '08:52:55.6'],
#  ['2020-04-09', '08:41:00.7'],
#  ['2020-04-09', '08:32:11.6'],
#  ['2020-04-09', '08:28:56.0'],
#  ['2020-04-09', '08:19:44.0'],
#  ['2020-04-09', '08:18:06.0'],
#  ['2020-04-09', '08:09:16.8'],
#  ['2020-04-09', '08:00:43.9'],
#  ['2020-04-09', '07:58:33.4'],
#  ['2020-04-09', '07:43:24.9'],
#  ['2020-04-09', '07:42:38.0'],
#  ['2020-04-09', '07:42:09.0'],
#  ['2020-04-09', '07:38:53.4'],
#  ['2020-04-09', '07:38:00.0'],
#  ['2020-04-09', '07:36:01.9'],
#  ['2020-04-09', '07:23:47.3'],
#  ['2020-04-09', '07:20:52.0'],
#  ['2020-04-09', '07:15:36.9'],
#  ['2020-04-09', '07:04:03.0'],
#  ['2020-04-09', '07:02:37.3'],
#  ['2020-04-09', '07:01:56.6'],
#  ['2020-04-09', '07:01:42.6'],
#  ['2020-04-09', '06:57:35.9'],
#  ['2020-04-09', '06:50:32.3']]

# %%
l=[i.text.strip() for i in table.select('td.tabev1,td.tabev2')]

[[l[i],l[i+1],l[i+2],l[i+3],l[i+4]] for i in range(0,len(l),5)]
# Out:
# [['9.33', 'S', '113.08', 'E', '3.3'],
#  ['45.79', 'N', '14.79', 'E', '1.6'],
#  ['1.37', 'N', '120.34', 'E', '3.8'],
#  ['24.86', 'N', '45.90', 'W', '5.1'],
#  ['13.25', 'N', '87.73', 'W', '4.6'],
#  ['2.88', 'S', '119.42', 'E', '2.5'],
#  ['48.19', 'N', '4.41', 'W', '2.6'],
#  ['51.54', 'N', '16.16', 'E', '2.5'],
#  ['6.31', 'S', '105.40', 'E', '3.4'],
#  ['19.22', 'N', '155.43', 'W', '2.2'],
#  ['35.90', 'S', '103.93', 'W', '5.0'],
#  ['2.13', 'S', '140.08', 'E', '3.5'],
#  ['5.27', 'N', '95.49', 'E', '2.9'],
#  ['19.61', 'N', '69.65', 'W', '3.2'],
#  ['5.31', 'N', '95.66', 'E', '3.2'],
#  ['1.67', 'S', '120.21', 'E', '4.2'],
#  ['3.36', 'S', '127.16', 'E', '2.6'],
#  ['17.95', 'N', '66.81', 'W', '2.4'],
#  ['5.39', 'N', '95.65', 'E', '3.9'],
#  ['24.18', 'S', '67.02', 'W', '5.0'],
#  ['47.55', 'N', '8.17', 'E', '1.9'],
#  ['40.57', 'N', '20.88', 'E', '2.9'],
#  ['18.03', 'N', '66.82', 'W', '2.2'],
#  ['38.48', 'N', '39.31', 'E', '2.2'],
#  ['3.00', 'S', '128.63', 'E', '2.6'],
#  ['6.72', 'S', '104.62', 'E', '3.3'],
#  ['48.20', 'N', '8.82', 'E', '2.4'],
#  ['45.63', 'N', '26.59', 'E', '2.6'],
#  ['40.77', 'N', '20.81', 'E', '2.0'],
#  ['5.20', 'S', '102.58', 'E', '3.3'],
#  ['16.81', 'N', '99.24', 'W', '4.1'],
#  ['44.48', 'N', '115.24', 'W', '2.5'],
#  ['44.55', 'N', '115.27', 'W', '2.5'],
#  ['17.83', 'N', '66.87', 'W', '2.2'],
#  ['44.53', 'N', '115.24', 'W', '2.9'],
#  ['51.98', 'N', '171.19', 'W', '4.1'],
#  ['15.40', 'N', '93.26', 'W', '4.2'],
#  ['3.01', 'S', '128.62', 'E', '3.4'],
#  ['17.84', 'N', '66.84', 'W', '2.7'],
#  ['2.88', 'S', '128.58', 'E', '4.6'],
#  ['39.15', 'N', '116.31', 'W', '2.4'],
#  ['38.44', 'N', '25.64', 'E', '2.5'],
#  ['8.28', 'S', '107.88', 'E', '4.5'],
#  ['33.51', 'N', '116.54', 'W', '2.8'],
#  ['38.91', 'N', '43.47', 'E', '2.1'],
#  ['12.65', 'N', '88.19', 'W', '4.2'],
#  ['38.42', 'N', '31.84', 'E', '2.2'],
#  ['17.86', 'N', '66.88', 'W', '2.3'],
#  ['45.75', 'N', '26.59', 'E', '2.9'],
#  ['37.29', 'N', '71.87', 'E', '4.3']]

# %% [markdown]
# #### Count the number of tweets by a given Twitter account.
# Ask the user for the handle (@handle) of a twitter account. You will need to include a ***try/except block*** for account names not found.
# <br>***Hint:*** the program should count the number of tweets for any provided account.

# %%
# This is the url you will scrape in this exercise 
# You will need to add the account credentials to this url
url = 'https://twitter.com/'

# %%
# your code here

# %% [markdown]
# #### Number of followers of a given twitter account
# Ask the user for the handle (@handle) of a twitter account. You will need to include a ***try/except block*** for account names not found.
# <br>***Hint:*** the program should count the followers for any provided account.

# %%
# This is the url you will scrape in this exercise 
# You will need to add the account credentials to this url
url = 'https://twitter.com/'

# %%
# your code here
twitter_account = input('From wich twitter account do you want to know the number of followers ? (use @) ')
twitter_account
# Out:
# From wich twitter account do you want to know the number of followers ? (use @) GroupeLaPoste
# 'GroupeLaPoste'

# %%
html=requests.get(url+twitter_account).content
soup=BeautifulSoup(html)
soup
text = soup.select("div:has(a[href='/GroupeLaPoste/followers'])")
text
#pd.DataFrame(all,columns=all[0])
# Out:
# [<div class="route-profile" data-at-shortcutkeys="{&quot;Enter&quot;:&quot;Afficher les d\u00e9tails du Tweet&quot;,&quot;o&quot;:&quot;Agrandir la photo&quot;,&quot;/&quot;:&quot;Recherche&quot;,&quot;?&quot;:&quot;Ce menu&quot;,&quot;j&quot;:&quot;Tweet suivant&quot;,&quot;k&quot;:&quot;Tweet pr\u00e9c\u00e9dent&quot;,&quot;Space&quot;:&quot;D\u00e9filer la page&quot;,&quot;.&quot;:&quot;Charger les nouveaux Tweets&quot;,&quot;gu&quot;:&quot;Aller vers l'utilisateur...&quot;}" id="doc">
#  <div class="topbar js-topbar">
#  <div class="js-banners" id="banners">
#  <div class="Banner Banner--aboveNav eu-cookie-notice">
#  <div class="Banner-contentContainer">
#  <div class="Banner-textContent">
#        En utilisant les services de Twitter, vous acceptez notre <a href="https://help.twitter.com/rules-and-policies/twitter-cookies" rel="noopener">Utilisation des cookies</a>. Nos partenaires et nous-mêmes opérons mondialement et utilisons des cookies, notamment à des fins de statistiques, de personnalisation et publicitaires.
#      </div>
#  <div class="Banner-actions">
#  <button type="button"><span class="Icon Icon--close"><span class="visuallyhidden">Fermer</span></span></button>
#  </div>
#  </div>
#  </div>
#  </div>
#  <div class="global-nav global-nav--newLoggedOut" data-section-term="top_nav">
#  <div class="global-nav-inner">
#  <div class="container">
#  <ul class="nav js-global-actions" id="global-actions" role="navigation">
#  <li class="home" data-global-action="home" id="global-nav-home">
#  <a class="js-nav js-tooltip js-dynamic-tooltip" data-component-context="home_nav" data-nav="home" data-placement="bottom" href="/">
#  <span class="Icon Icon--bird Icon--large"></span>
#  <span aria-hidden="true" class="text">Accueil</span>
#  <span class="u-hiddenVisually a11y-inactive-page-text">Accueil</span>
#  <span class="u-hiddenVisually a11y-active-page-text">Accueil, page courante.</span>
#  </a>
#  </li>
#  <li class="about" data-global-action="about" id="global-nav-about">
#  <a class="js-tooltip js-dynamic-tooltip" data-component-context="about_nav" data-nav="about" data-placement="bottom" href="/about" rel="noopener" target="_blank">
#  <span class="text">À propos</span>
#  </a>
#  </li>
#  </ul>
#  <div class="pull-right nav-extras">
#  <div role="search">
#  <form action="/search" class="t1-form form-search js-search-form" id="global-nav-search">
#  <label class="visuallyhidden" for="search-query">Recherche</label>
#  <input autocomplete="off" class="search-input" id="search-query" name="q" placeholder="Recherchez sur Twitter" spellcheck="false" type="text"/>
#  <span class="search-icon js-search-action">
#  <button class="Icon Icon--medium Icon--search nav-search" type="submit">
#  <span class="visuallyhidden">Recherchez sur Twitter</span>
#  </button>
#  </span>
#  <div class="dropdown-menu typeahead" role="listbox">
#  <div aria-hidden="true" class="dropdown-caret">
#  <div class="caret-outer"></div>
#  <div class="caret-inner"></div>
#  </div>
#  <div class="dropdown-inner js-typeahead-results" role="presentation">
#  <div class="typeahead-saved-searches" role="presentation">
#  <h3 class="typeahead-category-title saved-searches-title" id="saved-searches-heading">Recherches sauvegardées</h3>
#  <ul class="typeahead-items saved-searches-list" role="presentation">
#  <li class="typeahead-item typeahead-saved-search-item" role="presentation">
#  <span aria-hidden="true" class="Icon Icon--close"><span class="visuallyhidden">Supprimer</span></span>
#  <a aria-describedby="saved-searches-heading" class="js-nav" data-ds="saved_search" data-query-source="" data-search-query="" href="" role="option" tabindex="-1"></a>
#  </li>
#  </ul>
#  </div>
#  <ul class="typeahead-items typeahead-topics" role="presentation">
#  <li class="typeahead-item typeahead-topic-item" role="presentation">
#  <a class="js-nav" data-ds="topics" data-query-source="typeahead_click" data-search-query="" href="" role="option" tabindex="-1"></a>
#  </li>
#  </ul>
#  <ul class="typeahead-items typeahead-accounts social-context js-typeahead-accounts" role="presentation">
#  <li class="typeahead-item typeahead-account-item js-selectable" data-remote="true" data-score="" data-user-id="" data-user-screenname="" role="presentation">
#  <a class="js-nav" data-ds="account" data-query-source="typeahead_click" data-search-query="" role="option">
#  <div class="js-selectable typeahead-in-conversation hidden">
#  <span class="Icon Icon--follower Icon--small"></span>
#  <span class="typeahead-in-conversation-text">Dans cette conversation</span>
#  </div>
#  <img alt="" class="avatar size32"/>
#  <span class="typeahead-user-item-info account-group">
#  <span class="fullname"></span><span class="UserBadges"><span class="Icon Icon--verified js-verified hidden"><span class="u-hiddenVisually">Compte certifié</span></span><span class="Icon Icon--protected js-protected hidden"><span class="u-hiddenVisually">Tweets protégés</span></span></span><span class="UserNameBreak"> </span><span class="username u-dir" dir="ltr">@<b></b></span>
#  </span>
#  <span class="typeahead-social-context"></span>
#  </a>
#  </li>
#  <li class="js-selectable typeahead-accounts-shortcut js-shortcut" role="presentation"><a class="js-nav" data-ds="account_search" data-query-source="typeahead_click" data-search-query="" data-shortcut="true" href="" role="option"></a></li>
#  </ul>
#  <ul class="typeahead-items typeahead-trend-locations-list" role="presentation">
#  <li class="typeahead-item typeahead-trend-locations-item" role="presentation"><a class="js-nav" data-ds="trend_location" data-search-query="" href="" role="option" tabindex="-1"></a></li>
#  </ul>
#  <div class="typeahead-user-select" role="presentation">
#  <div class="typeahead-empty-suggestions" role="presentation">
#      Utilisateurs suggérés
#    </div>
#  <ul class="typeahead-items typeahead-selected js-typeahead-selected" role="presentation">
#  <li class="typeahead-item typeahead-selected-item js-selectable" data-remote="true" data-score="" data-user-id="" data-user-screenname="" role="presentation">
#  <a class="js-nav" data-ds="account" data-query-source="typeahead_click" data-search-query="" role="option">
#  <img alt="" class="avatar size32"/>
#  <span class="typeahead-user-item-info account-group">
#  <span class="select-status deselect-user js-deselect-user Icon Icon--check"></span>
#  <span class="select-status select-disabled Icon Icon--unfollow"></span>
#  <span class="fullname"></span><span class="UserBadges"><span class="Icon Icon--verified js-verified hidden"><span class="u-hiddenVisually">Compte certifié</span></span><span class="Icon Icon--protected js-protected hidden"><span class="u-hiddenVisually">Tweets protégés</span></span></span><span class="UserNameBreak"> </span><span class="username u-dir" dir="ltr">@<b></b></span>
#  </span>
#  </a>
#  </li>
#  <li class="typeahead-selected-end" role="presentation"></li>
#  </ul>
#  <ul class="typeahead-items typeahead-accounts js-typeahead-accounts" role="presentation">
#  <li class="typeahead-item typeahead-account-item js-selectable" data-remote="true" data-score="" data-user-id="" data-user-screenname="" role="presentation">
#  <a class="js-nav" data-ds="account" data-query-source="typeahead_click" data-search-query="" role="option">
#  <img alt="" class="avatar size32"/>
#  <span class="typeahead-user-item-info account-group">
#  <span class="select-status deselect-user js-deselect-user Icon Icon--check"></span>
#  <span class="select-status select-disabled Icon Icon--unfollow"></span>
#  <span class="fullname"></span><span class="UserBadges"><span class="Icon Icon--verified js-verified hidden"><span class="u-hiddenVisually">Compte certifié</span></span><span class="Icon Icon--protected js-protected hidden"><span class="u-hiddenVisually">Tweets protégés</span></span></span><span class="UserNameBreak"> </span><span class="username u-dir" dir="ltr">@<b></b></span>
#  </span>
#  </a>
#  </li>
#  <li class="typeahead-accounts-end" role="presentation"></li>
#  </ul>
#  </div>
#  <div class="typeahead-dm-conversations" role="presentation">
#  <ul class="typeahead-items typeahead-dm-conversation-items" role="presentation">
#  <li class="typeahead-item typeahead-dm-conversation-item" role="presentation">
#  <a role="option" tabindex="-1"></a>
#  </li>
#  </ul>
#  </div>
#  </div>
#  </div>
#  </form>
#  </div>
#  <ul class="nav secondary-nav language-dropdown">
#  <li class="dropdown js-language-dropdown">
#  <a class="dropdown-toggle js-dropdown-toggle" href="#supported_languages">
#  <small>Langue :</small> <span class="js-current-language">français</span> <b class="caret"></b>
#  </a>
#  <div class="dropdown-menu dropdown-menu--rightAlign is-forceRight">
#  <div class="dropdown-caret right">
#  <span class="caret-outer"> </span>
#  <span class="caret-inner"></span>
#  </div>
#  <ul id="supported_languages">
#  <li><a class="js-language-link js-tooltip" data-lang-code="id" href="?lang=id" rel="noopener" title="indonésien">Bahasa Indonesia</a></li>
#  <li><a class="js-language-link js-tooltip" data-lang-code="msa" href="?lang=msa" rel="noopener" title="malais">Bahasa Melayu</a></li>
#  <li><a class="js-language-link js-tooltip" data-lang-code="ca" href="?lang=ca" rel="noopener" title="catalan">Català</a></li>
#  <li><a class="js-language-link js-tooltip" data-lang-code="cs" href="?lang=cs" rel="noopener" title="tchèque">Čeština</a></li>
#  <li><a class="js-language-link js-tooltip" data-lang-code="da" href="?lang=da" rel="noopener" title="danois">Dansk</a></li>
#  <li><a class="js-language-link js-tooltip" data-lang-code="de" href="?lang=de" rel="noopener" title="allemand">Deutsch</a></li>
#  <li><a class="js-language-link js-tooltip" data-lang-code="en" href="?lang=en" rel="noopener" title="anglais">English</a></li>
#  <li><a class="js-language-link js-tooltip" data-lang-code="en-gb" href="?lang=en-gb" rel="noopener" title="anglais britannique">English UK</a></li>
#  <li><a class="js-language-link js-tooltip" data-lang-code="es" href="?lang=es" rel="noopener" title="espagnol">Español</a></li>
#  <li><a class="js-language-link js-tooltip" data-lang-code="fil" href="?lang=fil" rel="noopener" title="filipino">Filipino</a></li>
#  <li><a class="js-language-link js-tooltip" data-lang-code="hr" href="?lang=hr" rel="noopener" title="croate">Hrvatski</a></li>
#  <li><a class="js-language-link js-tooltip" data-lang-code="it" href="?lang=it" rel="noopener" title="italien">Italiano</a></li>
#  <li><a class="js-language-link js-tooltip" data-lang-code="hu" href="?lang=hu" rel="noopener" title="hongrois">Magyar</a></li>
#  <li><a class="js-language-link js-tooltip" data-lang-code="nl" href="?lang=nl" rel="noopener" title="néerlandais">Nederlands</a></li>
#  <li><a class="js-language-link js-tooltip" data-lang-code="no" href="?lang=no" rel="noopener" title="norvégien">Norsk</a></li>
#  <li><a class="js-language-link js-tooltip" data-lang-code="pl" href="?lang=pl" rel="noopener" title="polonais">Polski</a></li>
#  <li><a class="js-language-link js-tooltip" data-lang-code="pt" href="?lang=pt" rel="noopener" title="portugais">Português</a></li>
#  <li><a class="js-language-link js-tooltip" data-lang-code="ro" href="?lang=ro" rel="noopener" title="roumain">Română</a></li>
#  <li><a class="js-language-link js-tooltip" data-lang-code="sk" href="?lang=sk" rel="noopener" title="slovaque">Slovenčina</a></li>
#  <li><a class="js-language-link js-tooltip" data-lang-code="fi" href="?lang=fi" rel="noopener" title="finnois">Suomi</a></li>
#  <li><a class="js-language-link js-tooltip" data-lang-code="sv" href="?lang=sv" rel="noopener" title="suédois">Svenska</a></li>
#  <li><a class="js-language-link js-tooltip" data-lang-code="vi" href="?lang=vi" rel="noopener" title="vietnamien">Tiếng Việt</a></li>
#  <li><a class="js-language-link js-tooltip" data-lang-code="tr" href="?lang=tr" rel="noopener" title="turc">Türkçe</a></li>
#  <li><a class="js-language-link js-tooltip" data-lang-code="el" href="?lang=el" rel="noopener" title="grec">Ελληνικά</a></li>
#  <li><a class="js-language-link js-tooltip" data-lang-code="bg" href="?lang=bg" rel="noopener" title="bulgare">Български език</a></li>
#  <li><a class="js-language-link js-tooltip" data-lang-code="ru" href="?lang=ru" rel="noopener" title="russe">Русский</a></li>
#  <li><a class="js-language-link js-tooltip" data-lang-code="sr" href="?lang=sr" rel="noopener" title="serbe">Српски</a></li>
#  <li><a class="js-language-link js-tooltip" data-lang-code="uk" href="?lang=uk" rel="noopener" title="ukrainien">Українська мова</a></li>
#  <li><a class="js-language-link js-tooltip" data-lang-code="he" href="?lang=he" rel="noopener" title="hébreu">עִבְרִית</a></li>
#  <li><a class="js-language-link js-tooltip" data-lang-code="ar" href="?lang=ar" rel="noopener" title="arabe">العربية</a></li>
#  <li><a class="js-language-link js-tooltip" data-lang-code="fa" href="?lang=fa" rel="noopener" title="persan">فارسی</a></li>
#  <li><a class="js-language-link js-tooltip" data-lang-code="mr" href="?lang=mr" rel="noopener" title="marathi">मराठी</a></li>
#  <li><a class="js-language-link js-tooltip" data-lang-code="hi" href="?lang=hi" rel="noopener" title="hindi">हिन्दी</a></li>
#  <li><a class="js-language-link js-tooltip" data-lang-code="bn" href="?lang=bn" rel="noopener" title="bengali">বাংলা</a></li>
#  <li><a class="js-language-link js-tooltip" data-lang-code="gu" href="?lang=gu" rel="noopener" title="goudjerati">ગુજરાતી</a></li>
#  <li><a class="js-language-link js-tooltip" data-lang-code="ta" href="?lang=ta" rel="noopener" title="tamoul">தமிழ்</a></li>
#  <li><a class="js-language-link js-tooltip" data-lang-code="kn" href="?lang=kn" rel="noopener" title="kannada">ಕನ್ನಡ</a></li>
#  <li><a class="js-language-link js-tooltip" data-lang-code="th" href="?lang=th" rel="noopener" title="thaï">ภาษาไทย</a></li>
#  <li><a class="js-language-link js-tooltip" data-lang-code="ko" href="?lang=ko" rel="noopener" title="coréen">한국어</a></li>
#  <li><a class="js-language-link js-tooltip" data-lang-code="ja" href="?lang=ja" rel="noopener" title="japonais">日本語</a></li>
#  <li><a class="js-language-link js-tooltip" data-lang-code="zh-cn" href="?lang=zh-cn" rel="noopener" title="chinois simplifié">简体中文</a></li>
#  <li><a class="js-language-link js-tooltip" data-lang-code="zh-tw" href="?lang=zh-tw" rel="noopener" title="chinois traditionnel">繁體中文</a></li>
#  </ul>
#  </div>
#  <div class="js-front-language">
#  <form action="/sessions/change_locale" class="t1-form language" method="POST">
#  <input name="lang" type="hidden"/> <input name="redirect" type="hidden"/>
#  <input name="authenticity_token" type="hidden" value="7d13d23de36a03ccfba0fd76c5a5464e0029d834"/>
#  </form>
#  </div>
#  </li>
#  </ul>
#  <ul class="nav secondary-nav session-dropdown" id="session">
#  <li class="dropdown js-session">
#  <a class="dropdown-toggle js-dropdown-toggle dropdown-signin" data-nav="login" href="/login" id="signin-link" role="button">
#  <small>Vous avez déjà un compte ?</small> <span class="emphasize"> Se connecter</span><span class="caret"></span>
#  </a>
#  <div class="dropdown-menu dropdown-form dropdown-menu--rightAlign is-forceRight" id="signin-dropdown">
#  <div class="dropdown-caret right"> <span class="caret-outer"></span> <span class="caret-inner"></span> </div>
#  <div class="signin-dialog-body">
#  <div>Vous avez déjà un compte ?</div>
#  <form action="https://twitter.com/sessions" class="LoginForm js-front-signin" data-component="login_callout" data-element="form" method="post">
#  <div class="LoginForm-input LoginForm-username">
#  <input autocomplete="username" class="text-input email-input js-signin-email" name="session[username_or_email]" placeholder="Téléphone, email ou nom d'utilisateur" type="text"/>
#  </div>
#  <div class="LoginForm-input LoginForm-password">
#  <input autocomplete="current-password" class="text-input" name="session[password]" placeholder="Mot de passe" type="password"/>
#  </div>
#  <div class="LoginForm-rememberForgot">
#  <label>
#  <input checked="checked" name="remember_me" type="checkbox" value="1"/>
#  <span>Se souvenir de moi</span>
#  </label>
#  <span class="separator">·</span>
#  <a class="forgot" href="/account/begin_password_reset" rel="noopener">Mot de passe oublié ?</a>
#  </div>
#  <input class="EdgeButton EdgeButton--primary EdgeButton--medium submit js-submit" type="submit" value="Se connecter"/>
#  <input name="return_to_ssl" type="hidden" value="true"/>
#  <input name="scribe_log" type="hidden"/>
#  <input name="redirect_after_login" type="hidden" value="/GroupeLaPoste"/>
#  <input name="authenticity_token" type="hidden" value="7d13d23de36a03ccfba0fd76c5a5464e0029d834"/>
#  <input autocomplete="off" name="ui_metrics" type="hidden"/>
#  <script async="" src="/i/js_inst?c_name=ui_metrics"></script>
#  </form>
#  <hr/>
#  <div class="signup SignupForm">
#  <div class="SignupForm-header">Nouveau sur Twitter ?</div>
#  <a class="EdgeButton EdgeButton--secondary EdgeButton--medium u-block js-signup" data-component="signup_callout" data-element="dropdown" href="https://twitter.com/signup" role="button">S'inscrire
#                  </a>
#  </div>
#  </div>
#  </div>
#  </li>
#  </ul>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  <div class="topbar-spacer" style="padding-top: 108px;">
#  </div>
#  <div id="page-outer">
#  <div class="AppContent" id="page-container">
#  <style id="user-style-GroupeLaPoste">
#
#
#
#
#
#
#    a,
#    a:hover,
#    a:focus,
#    a:active {
#      color: #215382;
#    }
#
#    .u-textUserColor,
#    .u-textUserColorHover:hover,
#    .u-textUserColorHover:hover .ProfileTweet-actionCount,
#    .u-textUserColorHover:focus {
#      color: #215382 !important;
#    }
#
#    .u-borderUserColor,
#    .u-borderUserColorHover:hover,
#    .u-borderUserColorHover:focus {
#      border-color: #215382 !important;
#    }
#
#    .u-bgUserColor,
#    .u-bgUserColorHover:hover,
#    .u-bgUserColorHover:focus {
#      background-color: #215382 !important;
#    }
#
#    .u-dropdownUserColor > li:hover,
#    .u-dropdownUserColor > li:focus,
#    .u-dropdownUserColor > li > button:hover,
#    .u-dropdownUserColor > li > button:focus,
#    .u-dropdownUserColor > li > a:focus,
#    .u-dropdownUserColor > li > a:hover {
#      color: #fff !important;
#      background-color: #215382 !important;
#    }
#
#    .u-boxShadowInsetUserColorHover:hover,
#    .u-boxShadowInsetUserColorHover:focus {
#      box-shadow: inset 0 0 0 5px #215382 !important;
#    }
#
#    .u-dropdownOpenUserColor.dropdown.open .dropdown-toggle {
#      color: #215382;
#    }
#
#
#    .u-textUserColorLight {
#      color: #A6BACD !important;
#    }
#
#    .u-borderUserColorLight,
#    .u-borderUserColorLightFocus:focus,
#    .u-borderUserColorLightHover:hover,
#    .u-borderUserColorLightHover:focus {
#      border-color: #A6BACD !important;
#    }
#
#    .u-bgUserColorLight {
#      background-color: #A6BACD !important;
#    }
#
#
#    .u-boxShadowUserColorLighterFocus:focus {
#      box-shadow: 0 0 8px rgba(0, 0, 0, 0.05), inset 0 1px 2px rgba(33,83,130,0.25) !important;
#    }
#
#
#    .u-textUserColorLightest {
#      color: #E8EDF2 !important;
#    }
#
#    .u-borderUserColorLightest {
#      border-color: #E8EDF2 !important;
#    }
#
#    .u-bgUserColorLightest {
#      background-color: #E8EDF2 !important;
#    }
#
#
#    .u-textUserColorLighter {
#      color: #C7D4DF !important;
#    }
#
#    .u-borderUserColorLighter {
#      border-color: #C7D4DF !important;
#    }
#
#    .u-bgUserColorLighter {
#      background-color: #C7D4DF !important;
#    }
#
#
#    .u-bgUserColorDarkHover:hover {
#      background-color: #1F4A72 !important;
#    }
#
#    .u-borderUserColorDark {
#      border-color: #1F4A72 !important;
#    }
#
#
#    .u-bgUserColorDarkerActive:active {
#      background-color: #1E4163 !important;
#    }
#
#
#
#
#
#
#
#
#
#
#
#
#
#  a,
#  .btn-link,
#  .btn-link:focus,
#  .icon-btn,
#
#
#
#  .pretty-link b,
#  .pretty-link:hover s,
#  .pretty-link:hover b,
#  .pretty-link:focus s,
#  .pretty-link:focus b,
#
#  .metadata a:hover,
#  .metadata a:focus,
#
#  a.account-group:hover .fullname,
#  a.account-group:focus .fullname,
#  .account-summary:focus .fullname,
#
#  .message .message-text a,
#  .message .message-text button,
#  .stats a strong,
#  .plain-btn:hover,
#  .plain-btn:focus,
#  .dropdown.open .user-dropdown.plain-btn,
#  .open > .plain-btn,
#  #global-actions .new:before,
#  .module .list-link:hover,
#  .module .list-link:focus,
#
#  .stats a:hover,
#  .stats a:hover strong,
#  .stats a:focus,
#  .stats a:focus strong,
#
#  .find-friends-sources li:hover .source,
#
#
#
#
#
#  .stream-item a:hover .fullname,
#  .stream-item a:focus .fullname,
#
#  .stream-item .view-all-supplements:hover,
#  .stream-item .view-all-supplements:focus,
#
#  .tweet .time a:hover,
#  .tweet .time a:focus,
#  .tweet .details.with-icn b,
#  .tweet .details.with-icn .Icon,
#
#  .stream-item:hover .original-tweet .details b,
#  .stream-item .original-tweet.focus .details b,
#  .stream-item.open .original-tweet .details b,
#
#  .client-and-actions a:hover,
#  .client-and-actions a:focus,
#
#  .dismiss-btn:hover b,
#
#  .tweet .context .pretty-link:hover s,
#  .tweet .context .pretty-link:hover b,
#  .tweet .context .pretty-link:focus s,
#  .tweet .context .pretty-link:focus b,
#
#  .list .username a:hover,
#  .list .username a:focus,
#  .list-membership-container .create-a-list,
#  .list-membership-container .create-a-list:hover,
#  .new-tweets-bar,
#
#
#
#  .card .list-details a:hover,
#  .card .list-details a:focus,
#  .card .card-body:hover .attribution,
#  .card .card-body .attribution:focus {
#    color: #215382;
#  }
#
#
#
#
#
#    .FoundMediaSearch--keyboard .FoundMediaSearch-focusable.is-focused {
#      border-color: #215382;
#    }
#
#
#    .photo-selector:hover .btn,
#    .icon-btn:hover,
#    .icon-btn:active,
#    .icon-btn.active,
#    .icon-btn.enabled {
#      border-color: #215382;
#      border-color: rgba(33,83,130,0.4);
#      color: #215382;
#    }
#
#
#    .photo-selector:hover .btn,
#    .icon-btn:hover {
#      background-image: linear-gradient(rgba(255,255,255,0), rgba(33,83,130,0.1));
#    }
#
#    .icon-btn.disabled,
#    .icon-btn.disabled:hover,
#    .icon-btn[disabled],
#    .icon-btn[aria-disabled=true] {
#      color: #215382;
#    }
#
#
#
#
#    .EdgeButton--primary,
#    .EdgeButton--primary:focus {
#      background-color: #4D759B;
#      border-color: transparent;
#    }
#
#    .EdgeButton--primary:hover,
#    .EdgeButton--primary:active {
#      background-color: #215382;
#      border-color: #215382;
#    }
#
#    .EdgeButton--primary:focus {
#      box-shadow:
#        0 0 0 2px #FFFFFF,
#        0 0 0 4px #A6BACD;
#    }
#
#    .EdgeButton--primary:active {
#      box-shadow:
#        0 0 0 2px #FFFFFF,
#        0 0 0 4px #4D759B;
#    }
#
#
#
#
#    .EdgeButton--secondary,
#    .EdgeButton--secondary:hover,
#    .EdgeButton--secondary:focus,
#    .EdgeButton--secondary:active {
#      border-color: #215382;
#      color: #215382;
#    }
#
#    .EdgeButton--secondary:hover,
#    .EdgeButton--secondary:active {
#      background-color: #E8EDF2;
#    }
#
#    .EdgeButton--secondary:focus {
#      box-shadow:
#        0 0 0 2px #FFFFFF,
#        0 0 0 4px rgba(33,83,130,0.4);
#    }
#
#    .EdgeButton--secondary:active {
#      box-shadow:
#        0 0 0 2px #FFFFFF,
#        0 0 0 4px #215382;
#    }
#
#
#
#
#    .EdgeButton--invertedPrimary {
#      color: #215382 !important;
#    }
#
#    .EdgeButton--invertedPrimary:focus {
#      box-shadow:
#        0 0 0 2px #215382,
#        0 0 0 4px #A6BACD;
#    }
#
#    .EdgeButton--invertedPrimary:active {
#      box-shadow:
#        0 0 0 2px #215382,
#        0 0 0 4px #FFFFFF;
#    }
#
#
#
#
#    .EdgeButton--invertedSecondary {
#      background-color: #215382;
#    }
#
#    .EdgeButton--invertedSecondary:hover {
#      background-color: #4D759B;
#    }
#
#    .EdgeButton--invertedSecondary:focus {
#      box-shadow:
#        0 0 0 2px #215382,
#        0 0 0 4px #A6BACD;
#    }
#
#    .EdgeButton--invertedSecondary:active {
#      box-shadow:
#        0 0 0 2px #215382,
#        0 0 0 4px #FFFFFF;
#    }
#
#
#
#    .btn:focus,
#    .btn.focus,
#    .Button:focus,
#    .EmojiPicker-item.is-focused,
#    .EmojiPicker .EmojiCategoryIcon:focus,
#    .EmojiPicker-skinTone:focus + .EmojiPicker-skinToneSwatch,
#    a:focus > img:first-child:last-child,
#    button:focus {
#      box-shadow:
#        0 0 0 2px #FFFFFF,
#        0 0 2px 4px rgba(33,83,130,0.4);
#    }
#
#    .selected-stream-item:focus {
#      box-shadow: 0 0 0 3px rgba(33,83,130,0.4);
#    }
#
#
#    .js-navigable-stream.stream-table-view .selected-stream-item[tabindex="-1"]:focus {
#      outline: 3px solid rgba(33,83,130,0.4) !important;
#    }
#
#
#    .js-navigable-stream.stream-table-view .selected-stream-item:focus {
#      box-shadow: none;
#    }
#
#
#
#    .global-dm-nav.new.with-count .dm-new .count-inner {
#      background: #215382;
#    }
#
#    .global-nav .people .count .count-inner {
#      background: #215382;
#    }
#
#    .dropdown-menu li > a:hover,
#    .dropdown-menu li > a:focus,
#    .dropdown-menu .dropdown-link:hover,
#    .dropdown-menu .dropdown-link:focus,
#    .dropdown-menu .dropdown-link.is-focused,
#    .dropdown-menu li:hover .dropdown-link,
#    .dropdown-menu li:focus .dropdown-link,
#    .dropdown-menu .selected a,
#    .dropdown-menu .dropdown-link.selected {
#      background-color: #215382 !important;
#    }
#
#    /* for items in typeahead dropdown menu on logged in pages */
#    .dropdown-menu .typeahead-items li > a:focus,
#    .dropdown-menu .typeahead-items li > a:hover,
#    .dropdown-menu .typeahead-items .selected,
#    .dropdown-menu .typeahead-items .selected a {
#      background-color: #E8EDF2 !important;
#      color: #215382 !important;
#    }
#
#    .typeahead a:hover,
#    .typeahead a:hover strong,
#    .typeahead a:hover .fullname,
#    .typeahead .selected a,
#    .typeahead .selected strong,
#    .typeahead .selected .fullname,
#    .typeahead .selected .Icon--close {
#      color: #215382 !important;
#    }
#
#
#  .home-tweet-box,
#  .LiveVideo-tweetBox,
#  .RetweetDialog-commentBox {
#    background-color: #E8EDF2;
#  }
#
#  .top-timeline-tweetbox .timeline-tweet-box .tweet-form.condensed .tweet-box {
#    color: #215382;
#  }
#
#  .RichEditor,
#  .TweetBoxAttachments {
#    border-color: #C7D4DF;
#  }
#
#  input:focus,
#  textarea:focus,
#  div[contenteditable="true"]:focus,
#  div[contenteditable="true"].fake-focus,
#  div[contenteditable="plaintext-only"]:focus,
#  div[contenteditable="plaintext-only"].fake-focus {
#    border-color: #A6BACD;
#    box-shadow: inset 0 0 0 1px rgba(33,83,130,0.7);
#  }
#
#  .tweet-box textarea:focus,
#  .tweet-box input[type=text],
#  .currently-dragging .tweet-form.is-droppable .tweet-drag-help,
#  .tweet-box[contenteditable="true"]:focus,
#  .RichEditor.is-fakeFocus,
#  .RichEditor.is-fakeFocus ~ .TweetBoxAttachments {
#    border-color: #A6BACD;
#    box-shadow: 0 0 0 1px #A6BACD;
#  }
#
#  .MomentCapsuleItem.selected-stream-item:focus {
#    box-shadow: 0 0 0 3px rgba(33,83,130,0.4);
#  }
#
#
#
#
#  s,
#  .pretty-link:hover s,
#  .pretty-link:focus s,
#  .stream-item-activity-notification .latest-tweet .tweet-row a:hover s,
#  .stream-item-activity-notification .latest-tweet .tweet-row a:focus s {
#      color: #215382;
#  }
#
#
#
#  .vellip,
#  .vellip:before,
#  .vellip:after,
#  .conversation-module > li:after,
#  .conversation-module > li:before,
#  .ThreadedConversation--loneTweet:after,
#  .ThreadedConversation-tweet:not(.is-hiddenAncestor) ~ .ThreadedConversation-tweet:before,
#  .ThreadedConversation-tweet:after,
#  .ThreadedConversation-moreReplies:before,
#  .ThreadedConversation-viewOther:before,
#  .ThreadedConversation-unavailableTweet:before,
#  .ThreadedConversation-unavailableTweet:after,
#  .ThreadedConversation--permalinkTweetWithAncestors:before,
#  .mini-avatar-with-thread:before,
#  .permalink.self-thread-permalink-with-descendant .permalink-tweet-container:after,
#  .permalink.self-thread-permalink-with-descendant .inline-reply-tweetbox-container:after {
#      border-color: #A6BACD;
#  }
#
#
#
#
#  .tweet .sm-reply,
#  .tweet .sm-rt,
#  .tweet .sm-fav,
#  .tweet .sm-image,
#  .tweet .sm-video,
#  .tweet .sm-audio,
#  .tweet .sm-geo,
#  .tweet .sm-in,
#  .tweet .sm-trash,
#  .tweet .sm-more,
#  .tweet .sm-page,
#  .tweet .sm-embed,
#  .tweet .sm-summary,
#  .tweet .sm-chat,
#
#  .timelines-navigation .active .profile-nav-icon,
#  .timelines-navigation .profile-nav-icon:hover,
#  .timelines-navigation .profile-nav-link:focus .profile-nav-icon,
#
#  .sm-top-tweet {
#      background-color: #215382;
#  }
#
#  .enhanced-mini-profile .mini-profile .profile-summary {
#    background-image: url(https://pbs.twimg.com/profile_banners/57691450/1585924710/mobile);
#  }
#
#    #global-tweet-dialog .modal-header,
#    #Tweetstorm-dialog .modal-header {
#      border-bottom: solid 1px rgba(33,83,130,0.25);
#    }
#
#    #global-tweet-dialog .modal-tweet-form-container,
#    #Tweetstorm-dialog .modal-body {
#      background-color: #215382;
#      background: rgba(33,83,130,0.1);
#    }
#
#    .TweetstormDialog-reply-context .tweet-box-avatar:after,
#    .TweetstormDialog-reply-context .tweet-box-avatar:before,
#    .TweetstormDialog-tweet-box .tweet-box-avatar:after,
#    .TweetstormDialog-tweet-box .tweet-box-avatar:before {
#      border-color: #A6BACD;
#    }
#
#    .global-nav .search-input:focus,
#    .global-nav .search-input.focus {
#      border: 2px solid #215382;
#    }
#  }
#
#    .inline-reply-tweetbox {
#      background-color: #E8EDF2;
#    }
#
#  </style>
#  <div class="ProfileCanopy ProfileCanopy--withNav ProfileCanopy--large js-variableHeightTopBar">
#  <div class="ProfileCanopy-inner">
#  <div class="ProfileCanopy-header u-bgUserColor">
#  <div class="ProfileCanopy-headerBg">
#  <img alt="" src="https://pbs.twimg.com/profile_banners/57691450/1585924710/1500x500"/>
#  </div>
#  <div class="AppContainer">
#  <div class="ProfileCanopy-avatar">
#  <div class="ProfileAvatar">
#  <a class="ProfileAvatar-container u-block js-tooltip profile-picture" data-resolved-url-large="https://pbs.twimg.com/profile_images/996404812412485632/PrgvgVMl_400x400.jpg" data-url="https://pbs.twimg.com/profile_images/996404812412485632/PrgvgVMl_400x400.jpg" href="https://pbs.twimg.com/profile_images/996404812412485632/PrgvgVMl_400x400.jpg" rel="noopener" target="_blank" title="Le Groupe La Poste">
#  <img alt="Le Groupe La Poste" class="ProfileAvatar-image" src="https://pbs.twimg.com/profile_images/996404812412485632/PrgvgVMl_400x400.jpg"/>
#  </a>
#  </div>
#  </div>
#  <div class="ProfileCanopy-headerPromptAnchor"></div>
#  </div>
#  </div>
#  <div class="ProfileCanopy-navBar u-boxShadow">
#  <div class="AppContainer">
#  <div class="Grid Grid--withGutter">
#  <div class="Grid-cell u-size1of3 u-lg-size1of4">
#  <div class="ProfileCanopy-card" role="presentation">
#  <div class="ProfileCardMini">
#  <a class="ProfileCardMini-avatar profile-picture js-tooltip" data-resolved-url-large="https://pbs.twimg.com/profile_images/996404812412485632/PrgvgVMl.jpg" data-url="https://pbs.twimg.com/profile_images/996404812412485632/PrgvgVMl.jpg" href="https://pbs.twimg.com/profile_images/996404812412485632/PrgvgVMl.jpg" rel="noopener" target="_blank" title="Le Groupe La Poste">
#  <img alt="Le Groupe La Poste" class="ProfileCardMini-avatarImage" src="https://pbs.twimg.com/profile_images/996404812412485632/PrgvgVMl_normal.jpg"/>
#  </a>
#  <div class="ProfileCardMini-details">
#  <div class="ProfileNameTruncated account-group">
#  <div class="u-textTruncate u-inlineBlock ProfileNameTruncated-withBadges ProfileNameTruncated-withBadges--1">
#  <a class="fullname ProfileNameTruncated-link u-textInheritColor js-nav" data-aria-label-part="" href="/GroupeLaPoste">
#        Le Groupe La Poste</a></div><span class="UserBadges"><span class="Icon Icon--verified"><span class="u-hiddenVisually">Compte certifié</span></span></span>
#  </div>
#  <div class="ProfileCardMini-screenname">
#  <a class="ProfileCardMini-screennameLink u-linkComplex js-nav u-dir" dir="ltr" href="/GroupeLaPoste">
#  <span class="username u-dir" dir="ltr">@<b class="u-linkComplex-target">GroupeLaPoste</b></span>
#  </a>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  <div class="Grid-cell u-size2of3 u-lg-size3of4">
#  <div class="ProfileCanopy-nav">
#  <div class="ProfileNav" data-user-id="57691450" role="navigation">
#  <ul class="ProfileNav-list">
#  <li class="ProfileNav-item ProfileNav-item--tweets is-active">
#  <a class="ProfileNav-stat ProfileNav-stat--link u-borderUserColor u-textCenter js-tooltip js-nav" data-nav="tweets" tabindex="0" title="41 957 Tweets">
#  <span aria-hidden="true" class="ProfileNav-label">Tweets</span>
#  <span class="u-hiddenVisually">Tweets, page actuelle.</span>
#  <span class="ProfileNav-value" data-count="41957" data-is-compact="true">42 k
#              </span>
#  </a>
#  </li><li class="ProfileNav-item ProfileNav-item--following">
#  <a class="ProfileNav-stat ProfileNav-stat--link u-borderUserColor u-textCenter js-tooltip js-openSignupDialog js-nonNavigable u-textUserColor" data-nav="following" href="/GroupeLaPoste/following" title="5 206 Abonnements">
#  <span aria-hidden="true" class="ProfileNav-label">Abonnements</span>
#  <span class="u-hiddenVisually">Abonnements</span>
#  <span class="ProfileNav-value" data-count="5206" data-is-compact="false">5 206</span>
#  </a>
#  </li><li class="ProfileNav-item ProfileNav-item--followers">
#  <a class="ProfileNav-stat ProfileNav-stat--link u-borderUserColor u-textCenter js-tooltip js-openSignupDialog js-nonNavigable u-textUserColor" data-nav="followers" href="/GroupeLaPoste/followers" title="36 071 Abonnés">
#  <span aria-hidden="true" class="ProfileNav-label">Abonnés</span>
#  <span class="u-hiddenVisually">Abonnés</span>
#  <span class="ProfileNav-value" data-count="36071" data-is-compact="true">36,1 k</span>
#  </a>
#  </li><li class="ProfileNav-item ProfileNav-item--favorites" data-more-item=".ProfileNav-dropdownItem--favorites">
#  <a class="ProfileNav-stat ProfileNav-stat--link u-borderUserColor u-textCenter js-tooltip js-openSignupDialog js-nonNavigable u-textUserColor" data-nav="favorites" href="/GroupeLaPoste/likes" title="32 697 J'aime">
#  <span aria-hidden="true" class="ProfileNav-label">J'aime</span>
#  <span class="u-hiddenVisually">J'aime</span>
#  <span class="ProfileNav-value" data-count="32697" data-is-compact="true">32,7 k</span>
#  </a>
#  </li><li class="ProfileNav-item ProfileNav-item--lists" data-more-item=".ProfileNav-dropdownItem--lists">
#  <a class="ProfileNav-stat ProfileNav-stat--link u-borderUserColor u-textCenter js-tooltip js-openSignupDialog js-nonNavigable u-textUserColor" data-nav="all_lists" href="/GroupeLaPoste/lists" title="7 Listes">
#  <span aria-hidden="true" class="ProfileNav-label">Listes</span>
#  <span class="u-hiddenVisually">Listes</span>
#  <span class="ProfileNav-value" data-is-compact="false">7</span>
#  </a></li><li class="ProfileNav-item ProfileNav-item--moments" data-more-item=".ProfileNav-dropdownItem--userMoments">
#  <a class="ProfileNav-stat ProfileNav-stat--link u-borderUserColor u-textCenter js-tooltip js-openSignupDialog js-nonNavigable u-textUserColor" data-nav="user_moments" href="/GroupeLaPoste/moments" title="4 Moments">
#  <span aria-hidden="true" class="ProfileNav-label">Moments</span>
#  <span class="u-hiddenVisually">Moments</span>
#  <span class="ProfileNav-value" data-is-compact="false">4</span>
#  </a></li><li class="ProfileNav-item ProfileNav-item--more dropdown is-hidden"> <a class="ProfileNav-stat ProfileNav-stat--link ProfileNav-stat--moreLink js-openSignupDialog js-nonNavigable" href="#more" role="button">
#  <span class="ProfileNav-label"> </span>
#  <span class="ProfileNav-value">Plus <span class="ProfileNav-dropdownCaret Icon Icon--medium Icon--caretDown"></span></span>
#  </a>
#  <div class="dropdown-menu">
#  <div class="dropdown-caret">
#  <span class="caret-outer"></span>
#  <span class="caret-inner"></span>
#  </div>
#  <ul><li>
#  <a class="ProfileNav-dropdownItem ProfileNav-dropdownItem--favorites is-hidden u-bgUserColorHover u-bgUserColorFocus u-linkClean js-nav" href="/GroupeLaPoste/likes">J'aime</a></li><li>
#  <a class="ProfileNav-dropdownItem ProfileNav-dropdownItem--lists is-hidden u-bgUserColorHover u-bgUserColorFocus u-linkClean js-nav" href="/GroupeLaPoste/lists">Listes</a></li><li>
#  <a class="ProfileNav-dropdownItem ProfileNav-dropdownItem--userMoments is-hidden u-bgUserColorHover u-bgUserColorFocus u-linkClean js-nav" href="/GroupeLaPoste/moments">Moments</a></li></ul>
#  </div>
#  </li><li class="ProfileNav-item ProfileNav-item--userActions u-floatRight u-textRight with-rightCaret">
#  <div class="UserActions u-textLeft">
#  <div class="user-actions btn-group not-following" data-name="Le Groupe La Poste" data-protected="false" data-screen-name="GroupeLaPoste" data-user-id="57691450">
#  <span class="UserActions-moreActions u-inlineBlock">
#  <button class="js-tooltip unmute-button btn small plain-btn" data-placement="top" title="Réafficher @GroupeLaPoste" type="button">
#  <span class="Icon Icon--muted Icon--medium"><span class="visuallyhidden">Réafficher <span class="username u-dir u-textTruncate" dir="ltr">@<b>GroupeLaPoste</b></span></span></span>
#  </button><button class="first-load js-tooltip mute-button btn small plain-btn" data-placement="top" title="Masquer @GroupeLaPoste" type="button">
#  <span class="Icon Icon--unmuted Icon--medium"><span class="visuallyhidden">Masquer <span class="username u-dir u-textTruncate" dir="ltr">@<b>GroupeLaPoste</b></span></span></span>
#  </button></span><span class="user-actions-follow-button js-follow-btn follow-button">
#  <button class="EdgeButton EdgeButton--secondary EdgeButton--medium button-text follow-text" type="button">
#  <span aria-hidden="true">Suivre</span>
#  <span class="u-hiddenVisually">Suivre <span class="username u-dir u-textTruncate" dir="ltr">@<b>GroupeLaPoste</b></span></span>
#  </button>
#  <button class="EdgeButton EdgeButton--primary EdgeButton--medium button-text following-text" type="button">
#  <span aria-hidden="true">Abonné</span>
#  <span class="u-hiddenVisually">Abonné à <span class="username u-dir u-textTruncate" dir="ltr">@<b>GroupeLaPoste</b></span></span>
#  </button>
#  <button class="EdgeButton EdgeButton--danger EdgeButton--medium button-text unfollow-text" type="button">
#  <span aria-hidden="true">Se désabonner</span>
#  <span class="u-hiddenVisually">Se désabonner de <span class="username u-dir u-textTruncate" dir="ltr">@<b>GroupeLaPoste</b></span></span>
#  </button>
#  <button class="EdgeButton EdgeButton--invertedDanger EdgeButton--medium button-text blocked-text" type="button">
#  <span aria-hidden="true">Bloqué</span>
#  <span class="u-hiddenVisually">A bloqué <span class="username u-dir u-textTruncate" dir="ltr">@<b>GroupeLaPoste</b></span></span>
#  </button>
#  <button class="EdgeButton EdgeButton--danger EdgeButton--medium button-text unblock-text" type="button">
#  <span aria-hidden="true">Débloquer</span>
#  <span class="u-hiddenVisually">Débloquer <span class="username u-dir u-textTruncate" dir="ltr">@<b>GroupeLaPoste</b></span></span>
#  </button>
#  <button class="EdgeButton EdgeButton--secondary EdgeButton--medium button-text pending-text" type="button">
#  <span aria-hidden="true">En attente</span>
#  <span class="u-hiddenVisually">Demande d'abonnement à <span class="username u-dir u-textTruncate" dir="ltr">@<b>GroupeLaPoste</b></span> en attente</span>
#  </button>
#  <button class="EdgeButton EdgeButton--secondary EdgeButton--medium button-text cancel-text" type="button">
#  <span aria-hidden="true">Annuler</span>
#  <span class="u-hiddenVisually">Annuler votre demande d'abonnement à <span class="username u-dir u-textTruncate" dir="ltr">@<b>GroupeLaPoste</b></span></span>
#  </button>
#  </span>
#  </div>
#  </div>
#  </li>
#  </ul>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  <div class="AppContainer">
#  <div aria-labelledby="content-main-heading" class="AppContent-main content-main u-cf" role="main">
#  <div class="Grid Grid--withGutter">
#  <div class="Grid-cell u-size1of3 u-lg-size1of4">
#  <div class="Grid Grid--withGutter">
#  <div class="Grid-cell">
#  <div class="ProfileSidebar ProfileSidebar--withLeftAlignment">
#  <div class="ProfileHeaderCard">
#  <h1 class="ProfileHeaderCard-name">
#  <a class="ProfileHeaderCard-nameLink u-textInheritColor js-nav" href="/GroupeLaPoste">Le Groupe La Poste</a><span class="ProfileHeaderCard-badges"><a class="js-tooltip" data-placement="right" href="/help/verified" rel="noopener" target="_blank" title="Compte certifié"><span class="Icon Icon--verified"><span class="u-hiddenVisually">Compte certifié</span></span></a></span>
#  </h1>
#  <h2 class="ProfileHeaderCard-screenname u-inlineBlock u-dir" dir="ltr">
#  <a class="ProfileHeaderCard-screennameLink u-linkComplex js-nav" href="/GroupeLaPoste">
#  <span class="username u-dir" dir="ltr">@<b class="u-linkComplex-target">GroupeLaPoste</b></span>
#  </a>
#  </h2>
#  <p class="ProfileHeaderCard-bio u-dir" dir="ltr">Pour tt savoir de l'actu du Groupe <a class="twitter-hashtag pretty-link js-nav" data-query-source="hashtag_click" dir="ltr" href="/hashtag/LaPoste?src=hash"><s>#</s><b>LaPoste</b></a> et ses projets de modernisations ! <a class="twitter-hashtag pretty-link js-nav" data-query-source="hashtag_click" dir="ltr" href="/hashtag/LaPosteSEngage?src=hash"><s>#</s><b>LaPosteSEngage</b></a> <a class="twitter-hashtag pretty-link js-nav" data-query-source="hashtag_click" dir="ltr" href="/hashtag/TousEngag%C3%A9s?src=hash"><s>#</s><b>TousEngagés</b></a> <a class="twitter-hashtag pretty-link js-nav" data-query-source="hashtag_click" dir="ltr" href="/hashtag/SimplifierLaVie?src=hash"><s>#</s><b>SimplifierLaVie</b></a>  Service clients : <a class="tweet-url twitter-atreply pretty-link" data-mentioned-user-id="0" dir="ltr" href="/LisaLaPoste" rel="nofollow"><s>@</s><b>LisaLaPoste</b></a></p>
#  <div class="ProfileHeaderCard-location u-hidden">
#  <span aria-hidden="true" class="Icon Icon--geo Icon--medium" role="presentation"></span>
#  <span class="ProfileHeaderCard-locationText u-dir" dir="ltr">
#  </span>
#  </div>
#  <div class="ProfileHeaderCard-url">
#  <span aria-hidden="true" class="Icon Icon--url Icon--medium" role="presentation"></span>
#  <span class="ProfileHeaderCard-urlText u-dir"> <a class="u-textUserColor" href="https://t.co/9BSEcmuGi4" rel="me nofollow noopener" target="_blank" title="http://www.groupelaposte.com">
#      groupelaposte.com
#    </a>
#  </span>
#  </div>
#  <div class="ProfileHeaderCard-joinDate">
#  <span aria-hidden="true" class="Icon Icon--calendar Icon--medium" role="presentation"></span>
#  <span class="ProfileHeaderCard-joinDateText js-tooltip u-dir" dir="ltr" title="09:48 - 17 juil. 2009">Inscrit en juillet 2009</span>
#  </div>
#  <div class="ProfileHeaderCard-birthdate u-hidden">
#  <span aria-hidden="true" class="Icon Icon--balloon Icon--medium" role="presentation"></span>
#  <span class="ProfileHeaderCard-birthdateText u-dir" dir="ltr">
#  </span>
#  </div>
#  </div>
#  <div class="PhotoRail">
#  <div class="PhotoRail-heading">
#  <span aria-hidden="true" class="Icon Icon--camera Icon--medium" role="presentation"></span>
#  <span class="PhotoRail-headingText">
#  <a class="PhotoRail-headingWithCount js-nav" href="/GroupeLaPoste/media">
#   7 009 Photos et vidéos             </a>
#  <a class="PhotoRail-headingWithoutCount js-nav" href="/GroupeLaPoste/media">
#              Photos et vidéos
#            </a>
#  </span>
#  </div>
#  <div class="PhotoRail-mediaBox">
#  <span class="js-photoRailInsertPoint"></span>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  <div class="Grid-cell u-size2of3 u-lg-size3of4">
#  <div class="Grid Grid--withGutter">
#  <div class="Grid-cell">
#  <div class="js-profileClusterFollow"></div>
#  </div>
#  <div class="Grid-cell u-lg-size2of3" data-test-selector="ProfileTimeline">
#  <div class="ProfileHeading">
#  <div class="ProfileHeading-spacer"></div>
#  <div class="ProfileHeading-content">
#  <h2 class="ProfileHeading-title u-hiddenVisually" id="content-main-heading">Tweets</h2>
#  <ul class="ProfileHeading-toggle">
#  <li class="ProfileHeading-toggleItem is-active" data-element-term="tweets_toggle">
#  <span aria-hidden="true">Tweets</span>
#  <span class="u-hiddenVisually">Tweets, page courante.</span>
#  </li>
#  <li class="ProfileHeading-toggleItem u-textUserColor" data-element-term="tweets_with_replies_toggle">
#  <a class="ProfileHeading-toggleLink js-openSignupDialog js-nonNavigable" data-nav="tweets_with_replies_toggle" href="/GroupeLaPoste/with_replies">
#                    Tweets &amp; réponses
#                  </a>
#  </li>
#  <li class="ProfileHeading-toggleItem u-textUserColor" data-element-term="photos_and_videos_toggle">
#  <a class="ProfileHeading-toggleLink js-openSignupDialog js-nonNavigable" data-nav="photos_and_videos_toggle" href="/GroupeLaPoste/media">
#                    Médias
#                  </a>
#  </li>
#  </ul>
#  </div>
#  </div>
#  <div class="ProfileWarningTimeline" data-element-context="blocked_profile">
#  <h2 class="ProfileWarningTimeline-heading" id="content-main-heading">Vous avez bloqué <span class="username u-dir u-textTruncate" dir="ltr">@<b>GroupeLaPoste</b></span></h2>
#  <p class="ProfileWarningTimeline-explanation">Êtes-vous sûr de vouloir voir ces Tweets ? Les voir ne débloquera pas <span class="username u-dir u-textTruncate" dir="ltr">@<b>GroupeLaPoste</b></span></p>
#  <button class="EdgeButton EdgeButton--tertiary ProfileWarningTimeline-button">Oui, voir le profil</button>
#  </div>
#  <div class="ScrollBumpDialog modal-container" id="scroll-bump-dialog">
#  <div class="modal draggable">
#  <div class="modal-content clearfix">
#  <button class="modal-btn modal-close js-close" type="button">
#  <span class="Icon Icon--close Icon--medium">
#  <span class="visuallyhidden">Fermer</span>
#  </span>
#  </button>
#  <div class="modal-header">
#  <h3 class="modal-title">
#
#              Le Groupe La Poste s'est abonné
#          </h3>
#  </div>
#  <div class="modal-body">
#  <div class="loading">
#  <span class="spinner-bigger"></span>
#  </div>
#  <ol class="ScrollBumpDialog-usersList clearfix js-users-list"></ol>
#  </div>
#  </div>
#  </div>
#  </div>
#  <div class="ProfileTimeline" id="timeline">
#  <div class="stream-container" data-max-position="1248261416752201728" data-min-position="1247902588390924290">
#  <div class="stream-item js-new-items-bar-container">
#  </div>
#  <div class="stream">
#  <ol class="stream-items js-navigable-stream" id="stream-items-id">
#  <li class="js-stream-item stream-item stream-item js-pinned" data-item-id="1245722203288752129" data-item-type="tweet" data-suggestion-json='{"suggestion_details":{},"tweet_ids":"1245722203288752129","scribe_component":"tweet"}' id="stream-item-tweet-1245722203288752129">
#  <div class="tweet js-stream-tweet js-actionable-tweet js-profile-popup-actionable dismissible-content original-tweet js-original-tweet tweet-has-context has-cards user-pinned has-content" data-conversation-id="1245722203288752129" data-disclosure-type="" data-follows-you="false" data-has-cards="true" data-item-id="1245722203288752129" data-name="Le Groupe La Poste" data-permalink-path="/GroupeLaPoste/status/1245722203288752129" data-reply-to-users-json='[{"id_str":"57691450","screen_name":"GroupeLaPoste","name":"Le Groupe La Poste","emojified_name":{"text":"Le Groupe La Poste","emojified_text_as_html":"Le Groupe La Poste"}}]' data-screen-name="GroupeLaPoste" data-tweet-id="1245722203288752129" data-tweet-nonce="1245722203288752129-66c66644-7e05-45e7-ac10-d52fbd36fd0d" data-user-id="57691450" data-you-block="false" data-you-follow="false">
#  <div class="context">
#  <div class="tweet-context with-icn pinned">
#  <span class="Icon Icon--small Icon--pinned u-textUserColor"></span>
#  <span class="js-pinned-text" data-aria-label-part="">Tweet épinglé</span>
#  </div>
#  </div>
#  <div class="content">
#  <div class="stream-item-header">
#  <a class="account-group js-account-group js-action-profile js-user-profile-link js-nav" data-user-id="57691450" href="/GroupeLaPoste">
#  <img alt="" class="avatar js-action-profile-avatar" src="https://pbs.twimg.com/profile_images/996404812412485632/PrgvgVMl_bigger.jpg"/>
#  <span class="FullNameGroup">
#  <strong class="fullname show-popup-with-id u-textTruncate" data-aria-label-part="">Le Groupe La Poste</strong><span>‏</span><span class="UserBadges"><span class="Icon Icon--verified"><span class="u-hiddenVisually">Compte certifié</span></span></span><span class="UserNameBreak"> </span></span><span class="username u-dir u-textTruncate" data-aria-label-part="" dir="ltr">@<b>GroupeLaPoste</b></span></a>
#  <small class="time">
#  <a class="tweet-timestamp js-permalink js-nav js-tooltip" data-conversation-id="1245722203288752129" href="/GroupeLaPoste/status/1245722203288752129" title="07:38 - 2 avr. 2020"><span class="_timestamp js-short-timestamp" data-aria-label-part="last" data-long-form="true" data-time="1585838292" data-time-ms="1585838292000">2 avr.</span></a>
#  </small>
#  <div class="ProfileTweet-action ProfileTweet-action--more js-more-ProfileTweet-actions">
#  <div class="dropdown">
# ...
#  </button>
#  <button class="EdgeButton EdgeButton--danger EdgeButton--medium button-text unblock-text" type="button">
#  <span aria-hidden="true">Débloquer</span>
#  <span class="u-hiddenVisually">Débloquer <span class="username u-dir u-textTruncate" dir="ltr">@<b>GroupeLaPoste</b></span></span>
#  </button>
#  <button class="EdgeButton EdgeButton--secondary EdgeButton--medium button-text pending-text" type="button">
#  <span aria-hidden="true">En attente</span>
#  <span class="u-hiddenVisually">Demande d'abonnement à <span class="username u-dir u-textTruncate" dir="ltr">@<b>GroupeLaPoste</b></span> en attente</span>
#  </button>
#  <button class="EdgeButton EdgeButton--secondary EdgeButton--medium button-text cancel-text" type="button">
#  <span aria-hidden="true">Annuler</span>
#  <span class="u-hiddenVisually">Annuler votre demande d'abonnement à <span class="username u-dir u-textTruncate" dir="ltr">@<b>GroupeLaPoste</b></span></span>
#  </button>
#  </span>
#  </div>
#  </div>
#  </li>
#  </ul>
#  </div>
#  </div>
#  </div>,
#  <div class="ProfileCanopy-nav">
#  <div class="ProfileNav" data-user-id="57691450" role="navigation">
#  <ul class="ProfileNav-list">
#  <li class="ProfileNav-item ProfileNav-item--tweets is-active">
#  <a class="ProfileNav-stat ProfileNav-stat--link u-borderUserColor u-textCenter js-tooltip js-nav" data-nav="tweets" tabindex="0" title="41 957 Tweets">
#  <span aria-hidden="true" class="ProfileNav-label">Tweets</span>
#  <span class="u-hiddenVisually">Tweets, page actuelle.</span>
#  <span class="ProfileNav-value" data-count="41957" data-is-compact="true">42 k
#              </span>
#  </a>
#  </li><li class="ProfileNav-item ProfileNav-item--following">
#  <a class="ProfileNav-stat ProfileNav-stat--link u-borderUserColor u-textCenter js-tooltip js-openSignupDialog js-nonNavigable u-textUserColor" data-nav="following" href="/GroupeLaPoste/following" title="5 206 Abonnements">
#  <span aria-hidden="true" class="ProfileNav-label">Abonnements</span>
#  <span class="u-hiddenVisually">Abonnements</span>
#  <span class="ProfileNav-value" data-count="5206" data-is-compact="false">5 206</span>
#  </a>
#  </li><li class="ProfileNav-item ProfileNav-item--followers">
#  <a class="ProfileNav-stat ProfileNav-stat--link u-borderUserColor u-textCenter js-tooltip js-openSignupDialog js-nonNavigable u-textUserColor" data-nav="followers" href="/GroupeLaPoste/followers" title="36 071 Abonnés">
#  <span aria-hidden="true" class="ProfileNav-label">Abonnés</span>
#  <span class="u-hiddenVisually">Abonnés</span>
#  <span class="ProfileNav-value" data-count="36071" data-is-compact="true">36,1 k</span>
#  </a>
#  </li><li class="ProfileNav-item ProfileNav-item--favorites" data-more-item=".ProfileNav-dropdownItem--favorites">
#  <a class="ProfileNav-stat ProfileNav-stat--link u-borderUserColor u-textCenter js-tooltip js-openSignupDialog js-nonNavigable u-textUserColor" data-nav="favorites" href="/GroupeLaPoste/likes" title="32 697 J'aime">
#  <span aria-hidden="true" class="ProfileNav-label">J'aime</span>
#  <span class="u-hiddenVisually">J'aime</span>
#  <span class="ProfileNav-value" data-count="32697" data-is-compact="true">32,7 k</span>
#  </a>
#  </li><li class="ProfileNav-item ProfileNav-item--lists" data-more-item=".ProfileNav-dropdownItem--lists">
#  <a class="ProfileNav-stat ProfileNav-stat--link u-borderUserColor u-textCenter js-tooltip js-openSignupDialog js-nonNavigable u-textUserColor" data-nav="all_lists" href="/GroupeLaPoste/lists" title="7 Listes">
#  <span aria-hidden="true" class="ProfileNav-label">Listes</span>
#  <span class="u-hiddenVisually">Listes</span>
#  <span class="ProfileNav-value" data-is-compact="false">7</span>
#  </a></li><li class="ProfileNav-item ProfileNav-item--moments" data-more-item=".ProfileNav-dropdownItem--userMoments">
#  <a class="ProfileNav-stat ProfileNav-stat--link u-borderUserColor u-textCenter js-tooltip js-openSignupDialog js-nonNavigable u-textUserColor" data-nav="user_moments" href="/GroupeLaPoste/moments" title="4 Moments">
#  <span aria-hidden="true" class="ProfileNav-label">Moments</span>
#  <span class="u-hiddenVisually">Moments</span>
#  <span class="ProfileNav-value" data-is-compact="false">4</span>
#  </a></li><li class="ProfileNav-item ProfileNav-item--more dropdown is-hidden"> <a class="ProfileNav-stat ProfileNav-stat--link ProfileNav-stat--moreLink js-openSignupDialog js-nonNavigable" href="#more" role="button">
#  <span class="ProfileNav-label"> </span>
#  <span class="ProfileNav-value">Plus <span class="ProfileNav-dropdownCaret Icon Icon--medium Icon--caretDown"></span></span>
#  </a>
#  <div class="dropdown-menu">
#  <div class="dropdown-caret">
#  <span class="caret-outer"></span>
#  <span class="caret-inner"></span>
#  </div>
#  <ul><li>
#  <a class="ProfileNav-dropdownItem ProfileNav-dropdownItem--favorites is-hidden u-bgUserColorHover u-bgUserColorFocus u-linkClean js-nav" href="/GroupeLaPoste/likes">J'aime</a></li><li>
#  <a class="ProfileNav-dropdownItem ProfileNav-dropdownItem--lists is-hidden u-bgUserColorHover u-bgUserColorFocus u-linkClean js-nav" href="/GroupeLaPoste/lists">Listes</a></li><li>
#  <a class="ProfileNav-dropdownItem ProfileNav-dropdownItem--userMoments is-hidden u-bgUserColorHover u-bgUserColorFocus u-linkClean js-nav" href="/GroupeLaPoste/moments">Moments</a></li></ul>
#  </div>
#  </li><li class="ProfileNav-item ProfileNav-item--userActions u-floatRight u-textRight with-rightCaret">
#  <div class="UserActions u-textLeft">
#  <div class="user-actions btn-group not-following" data-name="Le Groupe La Poste" data-protected="false" data-screen-name="GroupeLaPoste" data-user-id="57691450">
#  <span class="UserActions-moreActions u-inlineBlock">
#  <button class="js-tooltip unmute-button btn small plain-btn" data-placement="top" title="Réafficher @GroupeLaPoste" type="button">
#  <span class="Icon Icon--muted Icon--medium"><span class="visuallyhidden">Réafficher <span class="username u-dir u-textTruncate" dir="ltr">@<b>GroupeLaPoste</b></span></span></span>
#  </button><button class="first-load js-tooltip mute-button btn small plain-btn" data-placement="top" title="Masquer @GroupeLaPoste" type="button">
#  <span class="Icon Icon--unmuted Icon--medium"><span class="visuallyhidden">Masquer <span class="username u-dir u-textTruncate" dir="ltr">@<b>GroupeLaPoste</b></span></span></span>
#  </button></span><span class="user-actions-follow-button js-follow-btn follow-button">
#  <button class="EdgeButton EdgeButton--secondary EdgeButton--medium button-text follow-text" type="button">
#  <span aria-hidden="true">Suivre</span>
#  <span class="u-hiddenVisually">Suivre <span class="username u-dir u-textTruncate" dir="ltr">@<b>GroupeLaPoste</b></span></span>
#  </button>
#  <button class="EdgeButton EdgeButton--primary EdgeButton--medium button-text following-text" type="button">
#  <span aria-hidden="true">Abonné</span>
#  <span class="u-hiddenVisually">Abonné à <span class="username u-dir u-textTruncate" dir="ltr">@<b>GroupeLaPoste</b></span></span>
#  </button>
#  <button class="EdgeButton EdgeButton--danger EdgeButton--medium button-text unfollow-text" type="button">
#  <span aria-hidden="true">Se désabonner</span>
#  <span class="u-hiddenVisually">Se désabonner de <span class="username u-dir u-textTruncate" dir="ltr">@<b>GroupeLaPoste</b></span></span>
#  </button>
#  <button class="EdgeButton EdgeButton--invertedDanger EdgeButton--medium button-text blocked-text" type="button">
#  <span aria-hidden="true">Bloqué</span>
#  <span class="u-hiddenVisually">A bloqué <span class="username u-dir u-textTruncate" dir="ltr">@<b>GroupeLaPoste</b></span></span>
#  </button>
#  <button class="EdgeButton EdgeButton--danger EdgeButton--medium button-text unblock-text" type="button">
#  <span aria-hidden="true">Débloquer</span>
#  <span class="u-hiddenVisually">Débloquer <span class="username u-dir u-textTruncate" dir="ltr">@<b>GroupeLaPoste</b></span></span>
#  </button>
#  <button class="EdgeButton EdgeButton--secondary EdgeButton--medium button-text pending-text" type="button">
#  <span aria-hidden="true">En attente</span>
#  <span class="u-hiddenVisually">Demande d'abonnement à <span class="username u-dir u-textTruncate" dir="ltr">@<b>GroupeLaPoste</b></span> en attente</span>
#  </button>
#  <button class="EdgeButton EdgeButton--secondary EdgeButton--medium button-text cancel-text" type="button">
#  <span aria-hidden="true">Annuler</span>
#  <span class="u-hiddenVisually">Annuler votre demande d'abonnement à <span class="username u-dir u-textTruncate" dir="ltr">@<b>GroupeLaPoste</b></span></span>
#  </button>
#  </span>
#  </div>
#  </div>
#  </li>
#  </ul>
#  </div>
#  </div>,
#  <div class="ProfileNav" data-user-id="57691450" role="navigation">
#  <ul class="ProfileNav-list">
#  <li class="ProfileNav-item ProfileNav-item--tweets is-active">
#  <a class="ProfileNav-stat ProfileNav-stat--link u-borderUserColor u-textCenter js-tooltip js-nav" data-nav="tweets" tabindex="0" title="41 957 Tweets">
#  <span aria-hidden="true" class="ProfileNav-label">Tweets</span>
#  <span class="u-hiddenVisually">Tweets, page actuelle.</span>
#  <span class="ProfileNav-value" data-count="41957" data-is-compact="true">42 k
#              </span>
#  </a>
#  </li><li class="ProfileNav-item ProfileNav-item--following">
#  <a class="ProfileNav-stat ProfileNav-stat--link u-borderUserColor u-textCenter js-tooltip js-openSignupDialog js-nonNavigable u-textUserColor" data-nav="following" href="/GroupeLaPoste/following" title="5 206 Abonnements">
#  <span aria-hidden="true" class="ProfileNav-label">Abonnements</span>
#  <span class="u-hiddenVisually">Abonnements</span>
#  <span class="ProfileNav-value" data-count="5206" data-is-compact="false">5 206</span>
#  </a>
#  </li><li class="ProfileNav-item ProfileNav-item--followers">
#  <a class="ProfileNav-stat ProfileNav-stat--link u-borderUserColor u-textCenter js-tooltip js-openSignupDialog js-nonNavigable u-textUserColor" data-nav="followers" href="/GroupeLaPoste/followers" title="36 071 Abonnés">
#  <span aria-hidden="true" class="ProfileNav-label">Abonnés</span>
#  <span class="u-hiddenVisually">Abonnés</span>
#  <span class="ProfileNav-value" data-count="36071" data-is-compact="true">36,1 k</span>
#  </a>
#  </li><li class="ProfileNav-item ProfileNav-item--favorites" data-more-item=".ProfileNav-dropdownItem--favorites">
#  <a class="ProfileNav-stat ProfileNav-stat--link u-borderUserColor u-textCenter js-tooltip js-openSignupDialog js-nonNavigable u-textUserColor" data-nav="favorites" href="/GroupeLaPoste/likes" title="32 697 J'aime">
#  <span aria-hidden="true" class="ProfileNav-label">J'aime</span>
#  <span class="u-hiddenVisually">J'aime</span>
#  <span class="ProfileNav-value" data-count="32697" data-is-compact="true">32,7 k</span>
#  </a>
#  </li><li class="ProfileNav-item ProfileNav-item--lists" data-more-item=".ProfileNav-dropdownItem--lists">
#  <a class="ProfileNav-stat ProfileNav-stat--link u-borderUserColor u-textCenter js-tooltip js-openSignupDialog js-nonNavigable u-textUserColor" data-nav="all_lists" href="/GroupeLaPoste/lists" title="7 Listes">
#  <span aria-hidden="true" class="ProfileNav-label">Listes</span>
#  <span class="u-hiddenVisually">Listes</span>
#  <span class="ProfileNav-value" data-is-compact="false">7</span>
#  </a></li><li class="ProfileNav-item ProfileNav-item--moments" data-more-item=".ProfileNav-dropdownItem--userMoments">
#  <a class="ProfileNav-stat ProfileNav-stat--link u-borderUserColor u-textCenter js-tooltip js-openSignupDialog js-nonNavigable u-textUserColor" data-nav="user_moments" href="/GroupeLaPoste/moments" title="4 Moments">
#  <span aria-hidden="true" class="ProfileNav-label">Moments</span>
#  <span class="u-hiddenVisually">Moments</span>
#  <span class="ProfileNav-value" data-is-compact="false">4</span>
#  </a></li><li class="ProfileNav-item ProfileNav-item--more dropdown is-hidden"> <a class="ProfileNav-stat ProfileNav-stat--link ProfileNav-stat--moreLink js-openSignupDialog js-nonNavigable" href="#more" role="button">
#  <span class="ProfileNav-label"> </span>
#  <span class="ProfileNav-value">Plus <span class="ProfileNav-dropdownCaret Icon Icon--medium Icon--caretDown"></span></span>
#  </a>
#  <div class="dropdown-menu">
#  <div class="dropdown-caret">
#  <span class="caret-outer"></span>
#  <span class="caret-inner"></span>
#  </div>
#  <ul><li>
#  <a class="ProfileNav-dropdownItem ProfileNav-dropdownItem--favorites is-hidden u-bgUserColorHover u-bgUserColorFocus u-linkClean js-nav" href="/GroupeLaPoste/likes">J'aime</a></li><li>
#  <a class="ProfileNav-dropdownItem ProfileNav-dropdownItem--lists is-hidden u-bgUserColorHover u-bgUserColorFocus u-linkClean js-nav" href="/GroupeLaPoste/lists">Listes</a></li><li>
#  <a class="ProfileNav-dropdownItem ProfileNav-dropdownItem--userMoments is-hidden u-bgUserColorHover u-bgUserColorFocus u-linkClean js-nav" href="/GroupeLaPoste/moments">Moments</a></li></ul>
#  </div>
#  </li><li class="ProfileNav-item ProfileNav-item--userActions u-floatRight u-textRight with-rightCaret">
#  <div class="UserActions u-textLeft">
#  <div class="user-actions btn-group not-following" data-name="Le Groupe La Poste" data-protected="false" data-screen-name="GroupeLaPoste" data-user-id="57691450">
#  <span class="UserActions-moreActions u-inlineBlock">
#  <button class="js-tooltip unmute-button btn small plain-btn" data-placement="top" title="Réafficher @GroupeLaPoste" type="button">
#  <span class="Icon Icon--muted Icon--medium"><span class="visuallyhidden">Réafficher <span class="username u-dir u-textTruncate" dir="ltr">@<b>GroupeLaPoste</b></span></span></span>
#  </button><button class="first-load js-tooltip mute-button btn small plain-btn" data-placement="top" title="Masquer @GroupeLaPoste" type="button">
#  <span class="Icon Icon--unmuted Icon--medium"><span class="visuallyhidden">Masquer <span class="username u-dir u-textTruncate" dir="ltr">@<b>GroupeLaPoste</b></span></span></span>
#  </button></span><span class="user-actions-follow-button js-follow-btn follow-button">
#  <button class="EdgeButton EdgeButton--secondary EdgeButton--medium button-text follow-text" type="button">
#  <span aria-hidden="true">Suivre</span>
#  <span class="u-hiddenVisually">Suivre <span class="username u-dir u-textTruncate" dir="ltr">@<b>GroupeLaPoste</b></span></span>
#  </button>
#  <button class="EdgeButton EdgeButton--primary EdgeButton--medium button-text following-text" type="button">
#  <span aria-hidden="true">Abonné</span>
#  <span class="u-hiddenVisually">Abonné à <span class="username u-dir u-textTruncate" dir="ltr">@<b>GroupeLaPoste</b></span></span>
#  </button>
#  <button class="EdgeButton EdgeButton--danger EdgeButton--medium button-text unfollow-text" type="button">
#  <span aria-hidden="true">Se désabonner</span>
#  <span class="u-hiddenVisually">Se désabonner de <span class="username u-dir u-textTruncate" dir="ltr">@<b>GroupeLaPoste</b></span></span>
#  </button>
#  <button class="EdgeButton EdgeButton--invertedDanger EdgeButton--medium button-text blocked-text" type="button">
#  <span aria-hidden="true">Bloqué</span>
#  <span class="u-hiddenVisually">A bloqué <span class="username u-dir u-textTruncate" dir="ltr">@<b>GroupeLaPoste</b></span></span>
#  </button>
#  <button class="EdgeButton EdgeButton--danger EdgeButton--medium button-text unblock-text" type="button">
#  <span aria-hidden="true">Débloquer</span>
#  <span class="u-hiddenVisually">Débloquer <span class="username u-dir u-textTruncate" dir="ltr">@<b>GroupeLaPoste</b></span></span>
#  </button>
#  <button class="EdgeButton EdgeButton--secondary EdgeButton--medium button-text pending-text" type="button">
#  <span aria-hidden="true">En attente</span>
#  <span class="u-hiddenVisually">Demande d'abonnement à <span class="username u-dir u-textTruncate" dir="ltr">@<b>GroupeLaPoste</b></span> en attente</span>
#  </button>
#  <button class="EdgeButton EdgeButton--secondary EdgeButton--medium button-text cancel-text" type="button">
#  <span aria-hidden="true">Annuler</span>
#  <span class="u-hiddenVisually">Annuler votre demande d'abonnement à <span class="username u-dir u-textTruncate" dir="ltr">@<b>GroupeLaPoste</b></span></span>
#  </button>
#  </span>
#  </div>
#  </div>
#  </li>
#  </ul>
#  </div>]

# %% [markdown]
# #### List all language names and number of related articles in the order they appear in wikipedia.org.

# %%
# This is the url you will scrape in this exercise
url = 'https://www.wikipedia.org/'

# %%
# your code here

# %% [markdown]
# #### A list with the different kind of datasets available in data.gov.uk.

# %%
# This is the url you will scrape in this exercise
url = 'https://data.gov.uk/'

# %%
# your code here

# %% [markdown]
# #### Display the top 10 languages by number of native speakers stored in a pandas dataframe.

# %%
# This is the url you will scrape in this exercise
url = 'https://en.wikipedia.org/wiki/List_of_languages_by_number_of_native_speakers'

# %%
# your code here

# %% [markdown]
# ## Bonus
# #### Scrape a certain number of tweets of a given Twitter account.

# %%
# This is the url you will scrape in this exercise 
# You will need to add the account credentials to this url
url = 'https://twitter.com/'

# %%
# your code here

# %% [markdown]
# #### Display IMDB's top 250 data (movie name, initial release, director name and stars) as a pandas dataframe.

# %%
# This is the url you will scrape in this exercise 
url = 'https://www.imdb.com/chart/top'

# %%
# your code here

# %% [markdown]
# #### Display the movie name, year and a brief summary of the top 10 random movies (IMDB) as a pandas dataframe.

# %%
#This is the url you will scrape in this exercise
url = 'http://www.imdb.com/chart/top'

# %%
# your code here

# %% [markdown]
# #### Find the live weather report (temperature, wind speed, description and weather) of a given city.

# %%
#https://openweathermap.org/current
city = input('Enter the city: ')
url = 'http://api.openweathermap.org/data/2.5/weather?'+'q='+city+'&APPID=b35975e18dc93725acb092f7272cc6b8&units=metric'

# %%
# your code here

# %% [markdown]
# #### Find the book name, price and stock availability as a pandas dataframe.

# %%
# This is the url you will scrape in this exercise. 
# It is a fictional bookstore created to be scraped. 
url = 'http://books.toscrape.com/'

# %%
# your code here
