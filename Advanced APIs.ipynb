# %%
import json
import requests
import pandas as pd

# %%
url = 'https://www.zalando.fr/api/catalog/articles?categories=promo-enfant&limit=84&offset=84'

# %%
#requests.get(url)

# %%
headers = """accept: */*
accept-encoding: gzip, deflate, br
accept-language: fr-FR,fr;q=0.9,en-US;q=0.8,en;q=0.7
cache-control: no-cache
cookie: usercentrics_enabled=true; fvgs_ml=mosaic; frsx=AAAAAF1EgptmlJZ7zD_VHJnpxVNOf_1cQCnDVaOsxIvgDk7IUAThkymPqXLLXIcw7suJunPWiHaR_vpOHUBm8ev71RiebVus2NLqdq_zhkuN9GmAgAQV5KgPnye6C_cwWQAr7KgqMOpYw7WqLRjWn0I=; Zalando-Client-Id=6e6ae2f3-7258-4d49-83b0-5b2c52cdbe4c; 8008f3fc-bdbc-49dc-a7d7-5672dea44794=with_consent_ui; bm_sz=D3DAED69956378BADDBA46693A021EDF~YAAQbOx7XN1VCjtxAQAApkPIWAcskhSzK5woYCcGSbvtGRLU1ToLhYgqiUFiWPwjXSPe4RAhPdsiQUKUudjEIY6fiMJVOkJ2C6qrC2HV+WKJeoKdQke1c7fhZqDbHmRc7I8QEEjhMbm2kBtlmseZsIp799uYOhCR4Kcs0cR0LahNGevQQ3m5xvQJnhHaC9Ug; ak_bmsc=73C8A13ABFB1CDD7AFC7087C72BBD18C5C7BEC6CC54E000023838D5E1F595F6C~; ncx=k; _ga=GA1.2.551996513.1586332455; _ga=GA1.2.551996513.1586332455; _gid=GA1.2.1927670042.1586332456; _gat_zalga=1; _gcl_au=1.1.1904207091.1586332459; _abck=CFA3DE56EBD878EA07E5DFC103D16FE0~-1~~-1~-1~-1
referer: https://www.zalando.fr/promo-enfant/
user-agent: Mozilla/5.0 (Macintosh; Intel Mac OS X 10_14_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/80.0.3987.149 Safari/537.36
x-xsrf-token: AAAAAF1EgptmlJZ7zD_VHJnpxVNOf_1cQCnDVaOsxIvgDk7IUAThkymPqXLLXIcw7suJunPWiHaR_vpOHUBm8ev71RiebVus2NLqdq_zhkuN9GmAgAQV5KgPnye6C_cwWQAr7KgqMOpYw7WqLRjWn0I=
x-zalando-catalog-nakadi-context: %7B%22previous_categories%22%3A%5B%22promo-enfant%22%5D%2C%22previous_selected_filters%22%3A%5B%5D%2C%22preselected_filters%22%3A%5B%5D%7D
x-zalando-octopus-tests: %5B%7B%22testName%22%3A%22lazy-article-images%22%2C%22testVariant%22%3A%22eager-load%22%2C%22testFeedbackId%22%3A%22930d47c9-bda8-4985-85b5-b6986c76544c%3Aclientid-6e6ae2f3-7258-4d49-83b0-5b2c52cdbe4c%22%7D%2C%7B%22testName%22%3A%22count-test%22%2C%22testVariant%22%3A%22default_count%22%2C%22testFeedbackId%22%3A%2200000000-0000-0000-0000-000000000000%3A__EMPTY__%22%7D%5D"""

# %%
headers = dict([i.split(': ') for i in headers.split('\n')])

# %%
response = requests.get(url, headers=headers)

# %%
results = response.json()

# %%
results
# Out:
# {'total_count': 34690,
#  'pagination': {'page_count': 413, 'current_page': 2, 'per_page': 84},
#  'sort': 'popularity',
#  'articles': [{'sku': 'CJ224B01P-N11',
#    'name': 'BABY 2 PACK - Pantalon classique - green',
#    'price': {'original': '17,95\xa0€',
#     'promotional': '14,35\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['0m', '3m', '6m', '9m', '12m', '18m', '24m'],
#    'url_key': 'carters-baby-2-pack-pantalon-classique-green-cj224b01p-n11',
#    'media': [{'path': 'CJ/22/4B/01/PN/11/CJ224B01P-N11@6.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False}],
#    'brand_name': "Carter's",
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'discountRate',
#      'value': '-20%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'clothing',
#    'delivery_promises': []},
# ...

# %%
pd.json_normalize(results)
# Out:
#    total_count        sort                                           articles  \
# 0        34690  popularity  [{'sku': 'CJ224B01P-N11', 'name': 'BABY 2 PACK...
#
#            query_path previous_page_path      next_page_path page_gender  \
# 0  /promo-enfant/?p=2     /promo-enfant/  /promo-enfant/?p=3        kids
#
#    premium                                            filters  \
# 0    False  [{'key': 'sizes', 'label': 'Taille', 'url_key'...
#
#    total_article_count  ... iconPaths.filters.standard_delivery_filter  \
# 0                34697  ...                            icons/truck.svg
#
#   iconPaths.filters.fast_delivery_filter iconPaths.filters.zalando_plus  \
# 0                   icons/truck-fast.svg         icons/plus-short-1.svg
#
#   iconPaths.mobileFilters.standard_delivery_filter  \
# 0                                  icons/truck.svg
#
#   iconPaths.mobileFilters.fast_delivery_filter  \
# 0                         icons/truck-fast.svg
#
# ...

# %%
results.keys()
# Out:
# dict_keys(['total_count', 'pagination', 'sort', 'articles', 'query_path', 'previous_page_path', 'next_page_path', 'query_params', 'page_gender', 'premium', 'filters', 'total_article_count', 'plusStatus', 'categoryTree', 'sortingKeys', 'breadcrumbs', 'querySemantics', 'pinnedFilters', 'searchDialogs', 'matchedSearchDialogRule', 'articlesToShow', 'octopusTests', 'locale', 'isLoggedIn', 'notification', 'resetFilters', 'selectedFilters', 'ssrArticleCount', 'feedbackId', 'variants', 'contentPositions', 'prideEnabled', 'lazyArticleImages', 'hideSearchTerm', 'iconPaths', 'teaser', 'inCatalogTeaser', 'entryPointTeasers', 'upperInCatTeaser', 'collection', 'carouselTeaser', 'wishlist', 'pills', 'sizeOnboardingDialog', 'showSearchDialogs', 'pinned'])

# %%
df = pd.json_normalize(results['articles'])

# %%
import time
df_final=pd.DataFrame()

for i in range(100):
    url = f'https://www.zalando.fr/api/catalog/articles?categories=promo-enfant&limit=84&offset={84*i}'
    headers = f"""accept': */*
    accept-encoding: gzip, deflate, br
    accept-language: en-GB,en-US;q=0.9,en;q=0.8
    cache-control: no-cache
    cookie: Zalando-Client-Id=3cda4f85-0064-4783-aaf9-ef19c3813900; ncx=k; bm_sz=8E874FB5F86BB196B586A30A1828DF4B~YAAQPOx7XLz8NR5xAQAAd1+/WAfjh3ZzXB2QCOE0yG69C1ckNKKMuFTeKXnx1ux/Bl9ODuZYvOR1YCkkEq8kQ7DMVFA11pVvjqRrk3xw6ycKnT1LMYc4vp44WJ4pBeGXsBotESD/5mNYCG/bk4srWDr9TN2ZQBOaBqPN4QJ7HKzKjkikTpgvWrkmSIVqljtU; frsx=AAAAADAybZedjiq6qM-21Mzty399mBJMNVBmqlXZRZPNwStfzzbclIL9213FHngO7J7zm62MCts4Id31uQ2IyJwk4psyiELzSStEizAYTXM1EW9b0WFEo1zCseeV1mB7jCE1UN8QSPeDu4NPkVvACXI=; _ga=GA1.2.1549168489.1586331871; ak_bmsc=D79F37902F03D5E2F67274330F0DF13A5C7BEC3C81570000DD808D5EFA45543D~; _abck=56C3EC87849D50BC89A932660A88A786~-1~~-1~-1~-1
    referer: https://www.zalando.fr/promo-enfant/?p={1 if i<2 else i-1}
    user-agent: Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/80.0.3987.116 Safari/537.36 OPR/67.0.3575.105
    x-xsrf-token: AAAAADAybZedjiq6qM-21Mzty399mBJMNVBmqlXZRZPNwStfzzbclIL9213FHngO7J7zm62MCts4Id31uQ2IyJwk4psyiELzSStEizAYTXM1EW9b0WFEo1zCseeV1mB7jCE1UN8QSPeDu4NPkVvACXI=
    x-zalando-catalog-nakadi-context: %7B%22previous_categories%22%3A%5B%22promo-enfant%22%5D%2C%22previous_selected_filters%22%3A%5B%5D%2C%22preselected_filters%22%3A%5B%5D%7D
    x-zalando-octopus-tests: %5B%7B%22testName%22%3A%22lazy-article-images%22%2C%22testVariant%22%3A%22lazy-load%22%2C%22testFeedbackId%22%3A%22930d47c9-bda8-4985-85b5-b6986c76544c%3Aclientid-3cda4f85-0064-4783-aaf9-ef19c3813900%22%7D%2C%7B%22testName%22%3A%22count-test%22%2C%22testVariant%22%3A%22default_count%22%2C%22testFeedbackId%22%3A%2200000000-0000-0000-0000-000000000000%3A__EMPTY__%22%7D%5D"""
    headers = dict([i.strip().split(': ') for i in headers.split('\n')])
    response = requests.get(url, headers=headers)
    results = response.json()
    df = pd.json_normalize(results['articles'])
    df_final = df_final.append(df)
    time.sleep(2)

# %%
df_final.shape
# Out:
# (8400, 19)

# %%
df_final.sku.duplicated().sum()
# Out:
# 8316

# %%
#Lab do the same with another category

url = 'https://www.zalando.fr/api/catalog/articles?categories=sport-homme&limit=84&offset=84&pinned=&sort=popularity'

# %%
headers ="""accept: */*
accept-encoding: gzip, deflate, br
accept-language: fr-FR,fr;q=0.9,en-US;q=0.8,en;q=0.7
cache-control: no-cache
cookie: usercentrics_enabled=true; fvgs_ml=mosaic; Zalando-Client-Id=6e6ae2f3-7258-4d49-83b0-5b2c52cdbe4c; bm_sz=D3DAED69956378BADDBA46693A021EDF~YAAQbOx7XN1VCjtxAQAApkPIWAcskhSzK5woYCcGSbvtGRLU1ToLhYgqiUFiWPwjXSPe4RAhPdsiQUKUudjEIY6fiMJVOkJ2C6qrC2HV+WKJeoKdQke1c7fhZqDbHmRc7I8QEEjhMbm2kBtlmseZsIp799uYOhCR4Kcs0cR0LahNGevQQ3m5xvQJnhHaC9Ug; ak_bmsc=73C8A13ABFB1CDD7AFC7087C72BBD18C5C7BEC6CC54E000023838D5E1F595F6C~; _ga=GA1.2.551996513.1586332455; _ga=GA1.2.551996513.1586332455; _gid=GA1.2.1927670042.1586332456; _gcl_au=1.1.1904207091.1586332459; frsx=AAAAAKKOf39cLD13SuzavtFJmPd1Iq5C8dttdW3n707aDPObKV7ePeadE7YRwaf5T4lp6AdGVaNk5cSE6Ap6M1u3PqhO_weagUHsXGqwo2-obZM4ZK9FehK6kRhxxIc-3im8vXO_rLCxIIgUBGkZ0gY=; ncx=m; _gat_zalga=1; _abck=CFA3DE56EBD878EA07E5DFC103D16FE0~-1~~-1~-1~-1
referer: https://www.zalando.fr/sport-homme/
user-agent: Mozilla/5.0 (Macintosh; Intel Mac OS X 10_14_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/80.0.3987.149 Safari/537.36
x-xsrf-token: AAAAAKKOf39cLD13SuzavtFJmPd1Iq5C8dttdW3n707aDPObKV7ePeadE7YRwaf5T4lp6AdGVaNk5cSE6Ap6M1u3PqhO_weagUHsXGqwo2-obZM4ZK9FehK6kRhxxIc-3im8vXO_rLCxIIgUBGkZ0gY=
x-zalando-catalog-nakadi-context: %7B%22previous_categories%22%3A%5B%22sport-homme%22%5D%2C%22previous_selected_filters%22%3A%5B%5D%2C%22preselected_filters%22%3A%5B%5D%7D
x-zalando-octopus-tests: %5B%7B%22testName%22%3A%22lazy-article-images%22%2C%22testVariant%22%3A%22eager-load%22%2C%22testFeedbackId%22%3A%22930d47c9-bda8-4985-85b5-b6986c76544c%3Aclientid-6e6ae2f3-7258-4d49-83b0-5b2c52cdbe4c%22%7D%2C%7B%22testName%22%3A%22count-test%22%2C%22testVariant%22%3A%22default_count%22%2C%22testFeedbackId%22%3A%2200000000-0000-0000-0000-000000000000%3A__EMPTY__%22%7D%5D"""

# %%
headers = dict([i.split(': ') for i in headers.split('\n')])

# %%
headers
# Out:
# {'accept': '*/*',
#  'accept-encoding': 'gzip, deflate, br',
#  'accept-language': 'fr-FR,fr;q=0.9,en-US;q=0.8,en;q=0.7',
#  'cache-control': 'no-cache',
# ...

# %%
response = requests.get(url, headers=headers)

# %%
response
# Out:
# <Response [200]>

# %%
results = response.json()

# %%
results
# Out:
# {'total_count': 11374,
#  'pagination': {'page_count': 136, 'current_page': 2, 'per_page': 84},
#  'sort': 'popularity',
#  'articles': [{'sku': 'UN242D0G3-Q11',
#    'name': 'CHALLENGER TRAINING  - T-shirt imprimé - black/white',
#    'price': {'original': '27,95\xa0€',
#     'promotional': '25,15\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['S', 'M', 'L', 'XL', 'XXL'],
#    'url_key': 'under-armour-challenger-iii-training-t-shirt-de-sport-un242d0g3-q11',
#    'media': [{'path': 'UN/24/2D/0G/3Q/11/UN242D0G3-Q11@8.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False},
#     {'path': 'UN/24/2D/0G/3Q/11/UN242D0G3-Q11@9.jpg',
#      'role': 'HOVER',
#      'packet_shot': False}],
#    'brand_name': 'Under Armour',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'discountRate',
# ...

# %%
pd.json_normalize(results)
# Out:
#    total_count        sort                                           articles  \
# 0        11374  popularity  [{'sku': 'UN242D0G3-Q11', 'name': 'CHALLENGER ...
#
#           query_path previous_page_path     next_page_path page_gender  \
# 0  /sport-homme/?p=2      /sport-homme/  /sport-homme/?p=3         men
#
#    premium                                            filters  \
# 0    False  [{'key': 'sizes', 'label': 'Taille', 'url_key'...
#
#    total_article_count  ...  \
# 0                11375  ...
#
#   inCatalogTeaser.content.tracking_data.cf_tracking_params.slot_id  \
# 0               cb224cac-736d-4e00-b757-d8a8007ef951
#
#   inCatalogTeaser.content.tracking_data.cf_tracking_params.flow_id  \
# 0                                   CM72-ZQKdWDlJV1A
#
#   inCatalogTeaser.content.tracking_data.cf_tracking_params.price  \
# 0                                           0.834414
#
#   inCatalogTeaser.content.tracking_data.cf_tracking_params.time_unit  \
# ...

# %%
results.keys()
# Out:
# dict_keys(['total_count', 'pagination', 'sort', 'articles', 'query_path', 'previous_page_path', 'next_page_path', 'query_params', 'page_gender', 'premium', 'filters', 'total_article_count', 'plusStatus', 'categoryTree', 'sortingKeys', 'breadcrumbs', 'querySemantics', 'pinnedFilters', 'searchDialogs', 'matchedSearchDialogRule', 'articlesToShow', 'octopusTests', 'locale', 'isLoggedIn', 'notification', 'resetFilters', 'selectedFilters', 'ssrArticleCount', 'feedbackId', 'variants', 'contentPositions', 'prideEnabled', 'lazyArticleImages', 'hideSearchTerm', 'iconPaths', 'teaser', 'inCatalogTeaser', 'entryPointTeasers', 'upperInCatTeaser', 'collection', 'carouselTeaser', 'wishlist', 'pills', 'sizeOnboardingDialog', 'showSearchDialogs', 'pinned'])

# %%
df = pd.json_normalize(results['articles'])

# %%
import time
df_final=pd.DataFrame()

for i in range(3):
    url = f'https://www.zalando.fr/api/catalog/articles?categories=sport-homme&limit=84&offset={84*i}'
    headers = f"""accept: */*
    accept-encoding: gzip, deflate, br
    accept-language: fr-FR,fr;q=0.9,en-US;q=0.8,en;q=0.7
    cache-control: no-cache
    cookie: usercentrics_enabled=true; fvgs_ml=mosaic; Zalando-Client-Id=6e6ae2f3-7258-4d49-83b0-5b2c52cdbe4c; bm_sz=D3DAED69956378BADDBA46693A021EDF~YAAQbOx7XN1VCjtxAQAApkPIWAcskhSzK5woYCcGSbvtGRLU1ToLhYgqiUFiWPwjXSPe4RAhPdsiQUKUudjEIY6fiMJVOkJ2C6qrC2HV+WKJeoKdQke1c7fhZqDbHmRc7I8QEEjhMbm2kBtlmseZsIp799uYOhCR4Kcs0cR0LahNGevQQ3m5xvQJnhHaC9Ug; ak_bmsc=73C8A13ABFB1CDD7AFC7087C72BBD18C5C7BEC6CC54E000023838D5E1F595F6C~; _ga=GA1.2.551996513.1586332455; _ga=GA1.2.551996513.1586332455; _gid=GA1.2.1927670042.1586332456; _gcl_au=1.1.1904207091.1586332459; frsx=AAAAAKKOf39cLD13SuzavtFJmPd1Iq5C8dttdW3n707aDPObKV7ePeadE7YRwaf5T4lp6AdGVaNk5cSE6Ap6M1u3PqhO_weagUHsXGqwo2-obZM4ZK9FehK6kRhxxIc-3im8vXO_rLCxIIgUBGkZ0gY=; ncx=m; _gat_zalga=1; _abck=CFA3DE56EBD878EA07E5DFC103D16FE0~-1~~-1~-1~-1
    referer: https://www.zalando.fr/sport-homme/?p={1 if i<2 else i-1}
    user-agent: Mozilla/5.0 (Macintosh; Intel Mac OS X 10_14_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/80.0.3987.149 Safari/537.36
    x-xsrf-token: AAAAAKKOf39cLD13SuzavtFJmPd1Iq5C8dttdW3n707aDPObKV7ePeadE7YRwaf5T4lp6AdGVaNk5cSE6Ap6M1u3PqhO_weagUHsXGqwo2-obZM4ZK9FehK6kRhxxIc-3im8vXO_rLCxIIgUBGkZ0gY=
    x-zalando-catalog-nakadi-context: %7B%22previous_categories%22%3A%5B%22sport-homme%22%5D%2C%22previous_selected_filters%22%3A%5B%5D%2C%22preselected_filters%22%3A%5B%5D%7D
    x-zalando-octopus-tests: %5B%7B%22testName%22%3A%22lazy-article-images%22%2C%22testVariant%22%3A%22eager-load%22%2C%22testFeedbackId%22%3A%22930d47c9-bda8-4985-85b5-b6986c76544c%3Aclientid-6e6ae2f3-7258-4d49-83b0-5b2c52cdbe4c%22%7D%2C%7B%22testName%22%3A%22count-test%22%2C%22testVariant%22%3A%22default_count%22%2C%22testFeedbackId%22%3A%2200000000-0000-0000-0000-000000000000%3A__EMPTY__%22%7D%5D"""
    headers = dict([i.strip().split(': ') for i in headers.split('\n')])
    response = requests.get(url, headers=headers)
    results = response.json()
    df = pd.json_normalize(results['articles'])
    df_final = df_final.append(df)
    time.sleep(1)

# %%
df_final.shape
# Out:
# (252, 19)

# %%
df_final.head()
# Out:
#              sku                                               name  \
# 0  PU142A0Z2-Q11  PUMA LQDCELL OPTIC DIM RUNNING SHOES MÄNNER - ...
# 1  N1242F0AL-Q11  ACADEMY18 - Veste imperméable - black/black/white
# 2  N1242E1AL-Q11           DRY SHORT - Short de sport - black/white
# 3  TH342F02M-Q11      NUPTSE ACONCAGUA - Veste sans manches - black
# 4  N1242E1AL-A11           DRY SHORT - Short de sport - white/black
#
#                                                sizes  \
# 0  [40, 41, 42, 42.5, 43, 44, 44.5, 45, 46, 47, 4...
# 1                                 [S, M, L, XL, XXL]
# 2                             [XS, S, M, L, XL, XXL]
# 3                                    [M, L, XL, XXL]
# 4                                  [XS, S, M, L, XL]
#
#                                              url_key  \
# 0  puma-chaussures-de-running-stables-puma-black-...
# 1  nike-performance-veste-de-survetement-blackbla...
# 2  nike-performance-dry-short-short-de-sport-n124...
# ...

# %%
df_final.sku.duplicated().sum()
# Out:
# 2

# %%
from bs4 import BeautifulSoup

# %%
url ='https://www.reuters.com/article/us-health-coronavirus-usa-food/from-deliveries-in-arizona-to-fish-markets-in-california-coronavirus-changes-how-we-buy-our-food-idUSKBN21Q1AS'

# %%
html = r.get(url).content

# %%
html[:100]
# Out:
# b'<!--[if !IE]> This has been served from cache <![endif]-->\n<!--[if !IE]> Request served from apache '

# %%
import re

# %%
re.findall(r"<meta name=\"analyticsAttributes\.title\" content=\"(.*?)\"",str(html))
#But not that nice to select everytime with Regex let's use selector through soup
# Out:
# ['From deliveries in Arizona to fish markets in California, coronavirus changes how we buy our food']

# %%
soup=BeautifulSoup(html)

# %%
[i.text for i in soup.select('h1')]
# Out:
# ['From deliveries in Arizona to fish markets in California, coronavirus changes how we buy our food']

# %%
list_of_tags=[f'h{i}' for i in range(1,8)]+['p']
list_of_tags
# Out:
# ['h1', 'h2', 'h3', 'h4', 'h5', 'h6', 'h7', 'p']

# %%
[i.text for i in soup.find_all(list_of_tags)]
# Out:
# ['From deliveries in Arizona to fish markets in California, coronavirus changes how we buy our food',
#  '4 Min Read',
#  '(Reuters) - Eric Cohn used to wear a respirator mask, goggles and gloves only to protect against mold and asbestos as he restored homes in Tucson, Arizona. Now he dons the same gear in his new job - shopping for quarantined customers.  ',
#  '“People ask me where I get this mask every day,” the 34-year-old said. “They say: you look good! I say I’m not trying to look good. I’m trying to be safe.” ',
#  'With over 90% of the U.S. population under orders to stay home to slow the spread of the coronavirus, Cohn is among a new class of front-line workers delivering food to people’s houses. ',
# ...

# %%
print('\n'.join([i.text for i in soup.find_all(list_of_tags)]))
# Out:
# From deliveries in Arizona to fish markets in California, coronavirus changes how we buy our food
# 4 Min Read
# (Reuters) - Eric Cohn used to wear a respirator mask, goggles and gloves only to protect against mold and asbestos as he restored homes in Tucson, Arizona. Now he dons the same gear in his new job - shopping for quarantined customers.
# “People ask me where I get this mask every day,” the 34-year-old said. “They say: you look good! I say I’m not trying to look good. I’m trying to be safe.”
# With over 90% of the U.S. population under orders to stay home to slow the spread of the coronavirus, Cohn is among a new class of front-line workers delivering food to people’s houses.
# ...

# %%
url="https://en.wikipedia.org/wiki/List_of_European_countries_by_life_expectancy"

# %%
 html=r.get(url).content

# %%
soup=BeautifulSoup(html)

# %%
table = soup.find_all('table',{'class','sortable wikitable'})[0]
table

# %%
rows=table.find_all('tr')

# %%
table=[[cell.strip() for cell in row.text.strip().split('\n') if cell.strip()!=''] for row in rows]

# %%
pd.DataFrame(table[1:],columns=table[0])
# Out:
#    Rank                 Country Life expectancy[1]
# 0     1               Monaco[2]               89.4
# 1     2           San Marino[3]               83.4
# 2     3             Switzerland               83.0
# 3     4                   Spain               82.8
# 4     5           Liechtenstein               82.7
# 5     6                   Italy               82.5
# 6     7                  Norway               82.5
# 7     8                 Iceland               82.5
# 8     9              Luxembourg               82.3
# 9    10                  France               82.3
# 10   11                  Sweden               82.2
# 11   12                   Malta               81.8
# 12   13                 Finland               81.8
# 13   14                 Ireland               81.6
# 14   15             Netherlands               81.5
# 15   16                Portugal               81.1
# 16   17                  Greece               81.0
# ...

# %%
url = 'https://en.wikipedia.org/wiki/List_of_countries_and_dependencies_by_population_density'

# %%
 html=r.get(url).content

# %%
soup=BeautifulSoup(html)

# %%
soup.select('table+h2+p+table')
# Out:
# [<table class="wikitable sortable" style="text-align:right">
#  <tbody><tr>
#  <th data-sort-type="number" rowspan="2">Rank</th>
#  <th rowspan="2">Country (or dependent territory)</th>
#  <th colspan="2">Area</th>
#  <th rowspan="2">Population</th>
#  <th colspan="2">Density</th>
#  <th rowspan="2">Date</th>
#  <th class="unsortable" rowspan="2">Population source
#  </th></tr>
#  <tr>
#  <th>km<sup>2</sup>
#  </th>
#  <th>mi<sup>2</sup>
#  </th>
#  <th>pop./km<sup>2</sup>
#  </th>
#  <th>pop./mi<sup>2</sup>
#  </th></tr>
#  <tr>
#  <td>1
#  </td>
# ...
